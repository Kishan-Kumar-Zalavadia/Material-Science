# %% [markdown]
# # Decision Tree

# %%
import json
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.multioutput import ClassifierChain
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
import numpy as np

# List of valid chemical elements (symbols) in the periodic table
periodic_elements = {
    "H", "He", "Li", "Be", "B", "C", "N", "O", "F", "Ne", "Na", "Mg", "Al", "Si", "P", "S", "Cl", "Ar", "K", "Ca",
    "Sc", "Ti", "V", "Cr", "Mn", "Fe", "Co", "Ni", "Cu", "Zn", "Ga", "Ge", "As", "Se", "Br", "Kr", "Rb", "Sr", "Y",
    "Zr", "Nb", "Mo", "Tc", "Ru", "Rh", "Pd", "Ag", "Cd", "In", "Sn", "Sb", "Te", "I", "Xe", "Cs", "Ba", "La", "Ce",
    "Pr", "Nd", "Pm", "Sm", "Eu", "Gd", "Tb", "Dy", "Ho", "Er", "Tm", "Yb", "Lu", "Hf", "Ta", "W", "Re", "Os", "Ir",
    "Pt", "Au", "Hg", "Tl", "Pb", "Bi", "Po", "At", "Rn", "Fr", "Ra", "Ac", "Th", "Pa", "U", "Np", "Pu", "Am", "Cm",
    "Bk", "Cf", "Es", "Fm", "Md", "No", "Lr", "Rf", "Db", "Sg", "Bh", "Hs", "Mt", "Ds", "Rg", "Cn", "Nh", "Fl", "Mc",
    "Lv", "Ts", "Og"
}

# Load the data
with open('allData_result.json') as f:
    data = json.load(f)

# Extracting composition data and converting to DataFrame
compositions = []
titles = []

for entry in data:
    # Set each element to 1 if it is present and it's a valid element, otherwise skip it
    composition = {element: 1 for element in entry['composition'].keys() if element in periodic_elements}
    titles.append(entry['title'])
    compositions.append(composition)

df = pd.DataFrame(compositions)
df.fillna(0, inplace=True)  # Fill NaN with 0 for elements not present

# Define features (X) and binary label columns (y)
X = df.copy()  # Features
y = df.copy()  # Multi-label targets, each element is its own label

# Initialize the base classifier
base_classifier = DecisionTreeClassifier(random_state=42)

# Set up K-fold cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)
fold = 1

# Loop over each fold
for train_index, test_index in kf.split(X):
    print(f"\n{'='*30} Fold {fold} Results {'='*30}")
    fold += 1

    # Split data into train and test sets for this fold
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    titles_train, titles_test = [titles[i] for i in train_index], [titles[i] for i in test_index]

    # Identify the columns (elements) that are present in the training data
    train_columns = X_train.columns[X_train.any() == 1]

    # Filter the test data to only include columns present in the training data
    X_train_filtered = X_train[train_columns]
    y_train_filtered = y_train[train_columns]
    X_test_filtered = X_test[train_columns]
    y_test_filtered = y_test[train_columns]

    # Initialize and train the classifier chain model with filtered data
    classifier_chain = ClassifierChain(base_classifier, order='random', random_state=42)
    classifier_chain.fit(X_train_filtered, y_train_filtered)

    # Predict on the filtered test set for this fold
    y_pred = classifier_chain.predict(X_test_filtered)

    # Print actual vs predicted compositions with titles for each object in the test set
    print("Title | Actual | Predicted")
    for title, actual, predicted in zip(titles_test, y_test_filtered.values, y_pred):
        actual_labels = ', '.join([col for col, val in zip(y.columns, actual) if val == 1])
        predicted_labels = ', '.join([col for col, val in zip(y.columns, predicted) if val == 1])
        print(f"{title} | Actual: {actual_labels} | Predicted: {predicted_labels}")

    # Calculate and print accuracy and classification report for this fold
    accuracy = accuracy_score(y_test_filtered, y_pred) * 100
    print(f"\nAccuracy for Fold {fold-1}: {accuracy:.2f}%")

    print("\nClassification Report for Fold:")
    print(classification_report(y_test_filtered, y_pred, target_names=train_columns, zero_division=0))
# Out:
# ============================== Fold 1 Results ==============================
# Title | Actual | Predicted
# paper-1 | Actual: Fe, Mn, Co, Cr, Si, Cu | Predicted: Fe, Mn, Co, Cr, Si, Cu
# paper-26 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
# paper-7 | Actual: Fe, Co, Cr, Ni, Al, Ti | Predicted: Fe, Co, Cr, Ni, Al, Ti
# paper-27 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
# paper-31 | Actual: Fe, Mn, Co, Cr, Si, H | Predicted: Fe, Mn, Co, Cr, Cu, H, Zn
# paper-138 | Actual: Fe, Cr, Cu, Al, Ti | Predicted: Co, Cr, Si, Al, Ti
#
# Accuracy for Fold 1: 66.67%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Fe       1.00      0.83      0.91         6
#           Mn       1.00      1.00      1.00         4
#           Co       0.83      1.00      0.91         5
#           Cr       1.00      1.00      1.00         6
#           Si       0.50      0.50      0.50         2
#           Cu       0.50      0.50      0.50         2
#           Ni       1.00      1.00      1.00         3
#           Al       1.00      1.00      1.00         2
#           Ti       1.00      1.00      1.00         2
#            U       0.00      0.00      0.00         0
#            N       0.00      0.00      0.00         0
#            I       0.00      0.00      0.00         0
#            C       0.00      0.00      0.00         0
#            H       1.00      1.00      1.00         1
#           Mo       0.00      0.00      0.00         0
#           Nb       0.00      0.00      0.00         0
#            W       0.00      0.00      0.00         0
#            B       0.00      0.00      0.00         0
#            S       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            P       0.00      0.00      0.00         0
#
#    micro avg       0.88      0.91      0.90        33
#    macro avg       0.42      0.42      0.42        33
# weighted avg       0.91      0.91      0.91        33
#  samples avg       0.89      0.91      0.89        33
#
#
# ============================== Fold 2 Results ==============================
# Title | Actual | Predicted
# paper-2 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
# paper-6 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
# paper-51 | Actual: U, N, I | Predicted: N, I
# paper-34 | Actual: Fe, Co, Cr, Ni, Al, Ti, I, H, Mo, Nb | Predicted: Fe, Co, Cr, Ni, Al, Ti, I, H, Mo, Nb
# paper-63 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
# paper-142 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
#
# Accuracy for Fold 2: 83.33%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Fe       1.00      1.00      1.00         5
#           Mn       1.00      1.00      1.00         4
#           Co       1.00      1.00      1.00         5
#           Cr       1.00      1.00      1.00         5
#           Si       0.00      0.00      0.00         0
#           Cu       0.00      0.00      0.00         0
#           Ni       1.00      1.00      1.00         5
#           Al       1.00      1.00      1.00         1
#           Ti       1.00      1.00      1.00         1
#            N       0.00      0.00      0.00         1
#            I       1.00      1.00      1.00         1
#            C       1.00      1.00      1.00         2
#            H       0.00      0.00      0.00         0
#           Mo       1.00      1.00      1.00         1
#           Nb       1.00      1.00      1.00         1
#            W       1.00      1.00      1.00         1
#            B       0.00      0.00      0.00         0
#            S       0.00      0.00      0.00         0
#           Zn       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            P       0.00      0.00      0.00         0
#
#    micro avg       1.00      0.97      0.98        33
#    macro avg       0.57      0.57      0.57        33
# weighted avg       0.97      0.97      0.97        33
#  samples avg       1.00      0.94      0.97        33
#
#
# ============================== Fold 3 Results ==============================
# Title | Actual | Predicted
# paper-4 | Actual: Fe, Co, Cr, Ni, Al, Ti | Predicted: Fe, Co, Cr, Ni, Al, Ti
# paper-5 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
# paper-22 | Actual: Fe, Mn, Co, Cr, Si, Cu | Predicted: Fe, Mn, Co, Cr, Si, Cu
# paper-33 | Actual: Fe, Co, Cr, Ni, Al, Ti, C, Mo, Nb, W | Predicted: Fe, Co, Cr, Ni, Al, Ti, C, Mo, Nb, W
# paper-133 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
#
# Accuracy for Fold 3: 100.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Fe       1.00      1.00      1.00         5
#           Mn       1.00      1.00      1.00         3
#           Co       1.00      1.00      1.00         5
#           Cr       1.00      1.00      1.00         5
#           Si       1.00      1.00      1.00         1
#           Cu       1.00      1.00      1.00         1
#           Ni       1.00      1.00      1.00         4
#           Al       1.00      1.00      1.00         2
#           Ti       1.00      1.00      1.00         2
#            U       0.00      0.00      0.00         0
#            N       0.00      0.00      0.00         0
#            I       0.00      0.00      0.00         0
#            C       1.00      1.00      1.00         1
#            H       0.00      0.00      0.00         0
#           Mo       1.00      1.00      1.00         1
#           Nb       1.00      1.00      1.00         1
#            W       1.00      1.00      1.00         1
#            B       0.00      0.00      0.00         0
#            S       0.00      0.00      0.00         0
#           Zn       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            P       0.00      0.00      0.00         0
#
#    micro avg       1.00      1.00      1.00        32
#    macro avg       0.59      0.59      0.59        32
# weighted avg       1.00      1.00      1.00        32
#  samples avg       1.00      1.00      1.00        32
#
#
# ============================== Fold 4 Results ==============================
# Title | Actual | Predicted
# paper-64 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
# paper-164 | Actual: C | Predicted: Fe, Cr, C
# paper-142 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
# paper-153 | Actual: N, I, C, H | Predicted: Fe, U, N, C, H
# Paper-200 | Actual: I, C | Predicted: Fe, U, N, C
#
# Accuracy for Fold 4: 40.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Fe       0.40      1.00      0.57         2
#           Mn       1.00      1.00      1.00         2
#           Co       1.00      1.00      1.00         2
#           Cr       0.67      1.00      0.80         2
#           Si       0.00      0.00      0.00         0
#           Cu       0.00      0.00      0.00         0
#           Ni       1.00      1.00      1.00         2
#           Al       0.00      0.00      0.00         0
#           Ti       0.00      0.00      0.00         0
#            U       0.00      0.00      0.00         0
#            N       0.50      1.00      0.67         1
#            I       0.00      0.00      0.00         2
#            C       1.00      1.00      1.00         3
#            H       1.00      1.00      1.00         1
#           Mo       0.00      0.00      0.00         0
#           Nb       0.00      0.00      0.00         0
#            W       0.00      0.00      0.00         0
#           Zn       0.00      0.00      0.00         0
#
#    micro avg       0.68      0.88      0.77        17
#    macro avg       0.36      0.44      0.39        17
# weighted avg       0.74      0.88      0.79        17
#  samples avg       0.64      0.85      0.70        17
#
#
# ============================== Fold 5 Results ==============================
# Title | Actual | Predicted
# paper-23 | Actual: Fe, Mn, Co, Cr, Si, Cu | Predicted: Fe, Mn, Co, Cr, Si, Cu
# paper-25 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
# paper-8 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
# paper-32 | Actual: Fe, Co, Cr, Ni, Al, Ti, C, Mo, Nb, W | Predicted: Fe, Co, Cr, Ni, Al, Ti, C, Mo, Nb, W
# paper-70 | Actual: Fe, Mn, Co, Cr, Ni, C | Predicted: Fe, Mn, Co, Cr, Ni, C
#
# Accuracy for Fold 5: 100.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Fe       1.00      1.00      1.00         5
#           Mn       1.00      1.00      1.00         4
#           Co       1.00      1.00      1.00         5
#           Cr       1.00      1.00      1.00         5
#           Si       1.00      1.00      1.00         1
#           Cu       1.00      1.00      1.00         1
#           Ni       1.00      1.00      1.00         4
#           Al       1.00      1.00      1.00         1
#           Ti       1.00      1.00      1.00         1
#            U       0.00      0.00      0.00         0
#            N       0.00      0.00      0.00         0
#            I       0.00      0.00      0.00         0
#            C       1.00      1.00      1.00         2
#            H       0.00      0.00      0.00         0
#           Mo       1.00      1.00      1.00         1
#           Nb       1.00      1.00      1.00         1
#            W       1.00      1.00      1.00         1
#            B       0.00      0.00      0.00         0
#            S       0.00      0.00      0.00         0
#           Zn       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            P       0.00      0.00      0.00         0
#
#    micro avg       1.00      1.00      1.00        32
#    macro avg       0.59      0.59      0.59        32
# weighted avg       1.00      1.00      1.00        32
#  samples avg       1.00      1.00      1.00        32

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# Initialize the Decision Tree classifier with parameters
decision_tree = DecisionTreeClassifier(random_state=42, max_depth=5)  # You can adjust `max_depth` as needed

# Fit the Decision Tree model using the entire dataset for visualization purposes
decision_tree.fit(X, y)

# Plot the Decision Tree
plt.figure(figsize=(20, 10))  # Adjust size as needed
plot_tree(decision_tree, feature_names=X.columns, class_names=[str(i) for i in y.columns], filled=True, rounded=True)
plt.show()

# %%
from sklearn.tree import export_graphviz
import pydotplus
from IPython.display import Image
from io import BytesIO
import matplotlib.pyplot as plt

# Initialize the Decision Tree classifier with parameters
decision_tree = DecisionTreeClassifier(random_state=42, max_depth=5)  # You can adjust `max_depth` as needed

# Fit the Decision Tree model using the entire dataset
decision_tree.fit(X, y)

# Export the decision tree to Graphviz format
dot_data = export_graphviz(decision_tree, out_file=None,
                           feature_names=X.columns,
                           class_names=[str(i) for i in y.columns],
                           filled=True, rounded=True, special_characters=True)

# Generate the graph using pydotplus
graph = pydotplus.graph_from_dot_data(dot_data)

# Save the decision tree to a PDF file
output_path = "decision_tree.pdf"
graph.write_pdf(output_path)

print(f"Decision tree saved as PDF: {output_path}")
# Out:
# Decision tree saved as PDF: decision_tree.pdf

# %% [markdown]
# ## Filter elements

# %%
import json
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.multioutput import ClassifierChain
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
import numpy as np

# List of valid chemical elements (symbols) in the periodic table
# Removed radioactive elements and noble gases.
periodic_elements = {
    "H", "Li", "Be", "B", "C", "N", "O", "F", "Na", "Mg", "Al", "Si", "P", "S", "Cl", "K", "Ca",
    "Sc", "Ti", "V", "Cr", "Mn", "Fe", "Co", "Ni", "Cu", "Zn", "Ga", "Ge", "As", "Se", "Br", "Rb", "Sr", "Y",
    "Zr", "Nb", "Mo", "Ru", "Rh", "Pd", "Ag", "Cd", "In", "Sn", "Sb", "Te", "I", "Cs", "Ba", "La", "Ce", "Pr",
    "Nd", "Sm", "Eu", "Gd", "Tb", "Dy", "Ho", "Er", "Tm", "Yb", "Lu", "Hf", "Ta", "W", "Re", "Os", "Ir", "Pt",
    "Au", "Hg", "Tl", "Pb", "Bi"
}



# Load the data
with open('allData_result.json') as f:
    data = json.load(f)

# Extracting composition data and converting to DataFrame
compositions = []
titles = []

for entry in data:
    # Set each element to 1 if it is present and it's a valid element, otherwise skip it
    composition = {element: 1 for element in entry['composition'].keys() if element in periodic_elements}
    titles.append(entry['title'])
    compositions.append(composition)

df = pd.DataFrame(compositions)
df.fillna(0, inplace=True)  # Fill NaN with 0 for elements not present

# Define features (X) and binary label columns (y)
X = df.copy()  # Features
y = df.copy()  # Multi-label targets, each element is its own label

# Initialize the base classifier
base_classifier = DecisionTreeClassifier(random_state=42)

# Set up K-fold cross-validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)
fold = 1

# Loop over each fold
for train_index, test_index in kf.split(X):
    print(f"\n{'='*30} Fold {fold} Results {'='*30}")
    fold += 1

    # Split data into train and test sets for this fold
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    titles_train, titles_test = [titles[i] for i in train_index], [titles[i] for i in test_index]

    # Identify the columns (elements) that are present in the training data
    train_columns = X_train.columns[X_train.any() == 1]

    # Filter the test data to only include columns present in the training data
    X_train_filtered = X_train[train_columns]
    y_train_filtered = y_train[train_columns]
    X_test_filtered = X_test[train_columns]
    y_test_filtered = y_test[train_columns]

    # Initialize and train the classifier chain model with filtered data
    classifier_chain = ClassifierChain(base_classifier, order='random', random_state=42)
    classifier_chain.fit(X_train_filtered, y_train_filtered)

    # Predict on the filtered test set for this fold
    y_pred = classifier_chain.predict(X_test_filtered)

    # Print actual vs predicted compositions with titles for each object in the test set
    print("Title | Actual | Predicted")
    for title, actual, predicted in zip(titles_test, y_test_filtered.values, y_pred):
        actual_labels = ', '.join([col for col, val in zip(y.columns, actual) if val == 1])
        predicted_labels = ', '.join([col for col, val in zip(y.columns, predicted) if val == 1])
        print(f"{title} | Actual: {actual_labels} | Predicted: {predicted_labels}")

    # Calculate and print accuracy and classification report for this fold
    accuracy = accuracy_score(y_test_filtered, y_pred) * 100
    print(f"\nAccuracy for Fold {fold-1}: {accuracy:.2f}%")

    print("\nClassification Report for Fold:")
    print(classification_report(y_test_filtered, y_pred, target_names=train_columns, zero_division=0))
# Out:
# ============================== Fold 1 Results ==============================
# Title | Actual | Predicted
# paper-1 | Actual: Fe, Mn, Co, Cr, Si, Cu | Predicted: Fe, Mn, Co, Cr, Si, Cu
# paper-26 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
# paper-7 | Actual: Fe, Co, Cr, Ni, Al, Ti | Predicted: Fe, Co, Cr, Ni, Al, Ti
# paper-27 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
# paper-31 | Actual: Fe, Mn, Co, Cr, Si, H | Predicted: Fe, Mn, Co, Cr, Zn
# paper-138 | Actual: Fe, Cr, Cu, Al, Ti | Predicted: Cr, Si, Cu, Al, Ti
#
# Accuracy for Fold 1: 66.67%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Fe       1.00      0.83      0.91         6
#           Mn       1.00      1.00      1.00         4
#           Co       1.00      1.00      1.00         5
#           Cr       1.00      1.00      1.00         6
#           Si       0.50      0.50      0.50         2
#           Cu       1.00      1.00      1.00         2
#           Ni       1.00      1.00      1.00         3
#           Al       1.00      1.00      1.00         2
#           Ti       1.00      1.00      1.00         2
#            N       0.00      0.00      0.00         0
#            I       0.00      0.00      0.00         0
#            C       0.00      0.00      0.00         0
#            H       0.00      0.00      0.00         1
#           Mo       0.00      0.00      0.00         0
#           Nb       0.00      0.00      0.00         0
#            W       0.00      0.00      0.00         0
#            B       0.00      0.00      0.00         0
#            S       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            P       0.00      0.00      0.00         0
#
#    micro avg       0.94      0.91      0.92        33
#    macro avg       0.42      0.42      0.42        33
# weighted avg       0.94      0.91      0.92        33
#  samples avg       0.93      0.91      0.92        33
#
#
# ============================== Fold 2 Results ==============================
# Title | Actual | Predicted
# paper-2 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
# paper-6 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
# paper-51 | Actual: N, I, C | Predicted: I, C
# paper-34 | Actual: Fe, Co, Cr, Ni, Al, Ti, C, Mo, Nb, W | Predicted: Fe, Co, Cr, Ni, Al, Ti, C, Mo, Nb, W
# paper-63 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
# paper-142 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
#
# Accuracy for Fold 2: 83.33%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Fe       1.00      1.00      1.00         5
#           Mn       1.00      1.00      1.00         4
#           Co       1.00      1.00      1.00         5
#           Cr       1.00      1.00      1.00         5
#           Si       0.00      0.00      0.00         0
#           Cu       0.00      0.00      0.00         0
#           Ni       1.00      1.00      1.00         5
#           Al       1.00      1.00      1.00         1
#           Ti       1.00      1.00      1.00         1
#            N       0.00      0.00      0.00         1
#            I       1.00      1.00      1.00         1
#            C       1.00      1.00      1.00         2
#            H       0.00      0.00      0.00         0
#           Mo       1.00      1.00      1.00         1
#           Nb       1.00      1.00      1.00         1
#            W       1.00      1.00      1.00         1
#            B       0.00      0.00      0.00         0
#            S       0.00      0.00      0.00         0
#           Zn       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            P       0.00      0.00      0.00         0
#
#    micro avg       1.00      0.97      0.98        33
#    macro avg       0.57      0.57      0.57        33
# weighted avg       0.97      0.97      0.97        33
#  samples avg       1.00      0.94      0.97        33
#
#
# ============================== Fold 3 Results ==============================
# Title | Actual | Predicted
# paper-4 | Actual: Fe, Co, Cr, Ni, Al, Ti | Predicted: Fe, Co, Cr, Ni, Al, Ti
# paper-5 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
# paper-22 | Actual: Fe, Mn, Co, Cr, Si, Cu | Predicted: Fe, Mn, Co, Cr, Si, Cu
# paper-33 | Actual: Fe, Co, Cr, Ni, Al, Ti, C, Mo, Nb, W | Predicted: Fe, Co, Cr, Ni, Al, Ti, C, Mo, Nb, W
# paper-133 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
#
# Accuracy for Fold 3: 100.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Fe       1.00      1.00      1.00         5
#           Mn       1.00      1.00      1.00         3
#           Co       1.00      1.00      1.00         5
#           Cr       1.00      1.00      1.00         5
#           Si       1.00      1.00      1.00         1
#           Cu       1.00      1.00      1.00         1
#           Ni       1.00      1.00      1.00         4
#           Al       1.00      1.00      1.00         2
#           Ti       1.00      1.00      1.00         2
#            N       0.00      0.00      0.00         0
#            I       0.00      0.00      0.00         0
#            C       1.00      1.00      1.00         1
#            H       0.00      0.00      0.00         0
#           Mo       1.00      1.00      1.00         1
#           Nb       1.00      1.00      1.00         1
#            W       1.00      1.00      1.00         1
#            B       0.00      0.00      0.00         0
#            S       0.00      0.00      0.00         0
#           Zn       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            P       0.00      0.00      0.00         0
#
#    micro avg       1.00      1.00      1.00        32
#    macro avg       0.62      0.62      0.62        32
# weighted avg       1.00      1.00      1.00        32
#  samples avg       1.00      1.00      1.00        32
#
#
# ============================== Fold 4 Results ==============================
# Title | Actual | Predicted
# paper-64 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
# paper-164 | Actual: C | Predicted: I, C
# paper-142 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
# paper-153 | Actual: N, I, C, H | Predicted: N, I, C, H
# Paper-200 | Actual: I, C | Predicted: I, C
#
# Accuracy for Fold 4: 80.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Fe       1.00      1.00      1.00         2
#           Mn       1.00      1.00      1.00         2
#           Co       1.00      1.00      1.00         2
#           Cr       1.00      1.00      1.00         2
#           Si       0.00      0.00      0.00         0
#           Cu       0.00      0.00      0.00         0
#           Ni       1.00      1.00      1.00         2
#           Al       0.00      0.00      0.00         0
#           Ti       0.00      0.00      0.00         0
#            N       1.00      1.00      1.00         1
#            I       0.67      1.00      0.80         2
#            C       1.00      1.00      1.00         3
#            H       1.00      1.00      1.00         1
#           Mo       0.00      0.00      0.00         0
#           Nb       0.00      0.00      0.00         0
#            W       0.00      0.00      0.00         0
#           Zn       0.00      0.00      0.00         0
#
#    micro avg       0.94      1.00      0.97        17
#    macro avg       0.51      0.53      0.52        17
# weighted avg       0.96      1.00      0.98        17
#  samples avg       0.90      1.00      0.93        17
#
#
# ============================== Fold 5 Results ==============================
# Title | Actual | Predicted
# paper-23 | Actual: Fe, Mn, Co, Cr, Si, Cu | Predicted: Fe, Mn, Co, Cr, Si, Cu
# paper-25 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
# paper-8 | Actual: Fe, Mn, Co, Cr, Ni | Predicted: Fe, Mn, Co, Cr, Ni
# paper-32 | Actual: Fe, Co, Cr, Ni, Al, Ti, C, Mo, Nb, W | Predicted: Fe, Co, Cr, Ni, Al, Ti, C, Mo, Nb, W
# paper-70 | Actual: Fe, Mn, Co, Cr, Ni, C | Predicted: Fe, Mn, Co, Cr, Ni, C
#
# Accuracy for Fold 5: 100.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Fe       1.00      1.00      1.00         5
#           Mn       1.00      1.00      1.00         4
#           Co       1.00      1.00      1.00         5
#           Cr       1.00      1.00      1.00         5
#           Si       1.00      1.00      1.00         1
#           Cu       1.00      1.00      1.00         1
#           Ni       1.00      1.00      1.00         4
#           Al       1.00      1.00      1.00         1
#           Ti       1.00      1.00      1.00         1
#            N       0.00      0.00      0.00         0
#            I       0.00      0.00      0.00         0
#            C       1.00      1.00      1.00         2
#            H       0.00      0.00      0.00         0
#           Mo       1.00      1.00      1.00         1
#           Nb       1.00      1.00      1.00         1
#            W       1.00      1.00      1.00         1
#            B       0.00      0.00      0.00         0
#            S       0.00      0.00      0.00         0
#           Zn       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            P       0.00      0.00      0.00         0
#
#    micro avg       1.00      1.00      1.00        32
#    macro avg       0.62      0.62      0.62        32
# weighted avg       1.00      1.00      1.00        32
#  samples avg       1.00      1.00      1.00        32

# %% [markdown]
# # New data

# %%
import json
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.multioutput import ClassifierChain
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
import numpy as np

# List of valid chemical elements (symbols) in the periodic table
# Removed radioactive elements and noble gases.
periodic_elements = {
    "H", "Li", "Be", "B", "C", "N", "O", "F", "Na", "Mg", "Al", "Si", "P", "S", "Cl", "K", "Ca",
    "Sc", "Ti", "V", "Cr", "Mn", "Fe", "Co", "Ni", "Cu", "Zn", "Ga", "Ge", "As", "Se", "Br", "Rb", "Sr", "Y",
    "Zr", "Nb", "Mo", "Ru", "Rh", "Pd", "Ag", "Cd", "In", "Sn", "Sb", "Te", "I", "Cs", "Ba", "La", "Ce", "Pr",
    "Nd", "Sm", "Eu", "Gd", "Tb", "Dy", "Ho", "Er", "Tm", "Yb", "Lu", "Hf", "Ta", "W", "Re", "Os", "Ir", "Pt",
    "Au", "Hg", "Tl", "Pb", "Bi"
}

# Load the data
with open('allData_result.json') as f:
    data = json.load(f)

# Extracting composition data and converting to DataFrame
compositions = []
titles = []

for entry in data:
    # Check if 'composition' exists and is not None
    if not entry.get('composition'):
        # print(f"Skipping entry with title '{entry.get('title', 'Unknown Title')}' due to missing 'composition'")
        continue
    # Set each element to 1 if it is present and it's a valid element, otherwise skip it
    composition = {element: 1 for element in entry['composition'].keys() if element in periodic_elements}
    titles.append(entry['title'])
    compositions.append(composition)

# Convert compositions to DataFrame
df = pd.DataFrame(compositions)
df.fillna(0, inplace=True)  # Fill NaN with 0 for elements not present

# Define features (X) and binary label columns (y)
X = df.copy()  # Features
y = df.copy()  # Multi-label targets, each element is its own label

# Initialize the base classifier
base_classifier = DecisionTreeClassifier(random_state=42)

# Set up K-fold cross-validation
kf = KFold(n_splits=10, shuffle=True, random_state=42)
fold = 1

# Loop over each fold
for train_index, test_index in kf.split(X):
    print(f"\n{'='*30} Fold {fold} Results {'='*30}")
    fold += 1

    # Split data into train and test sets for this fold
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    titles_train, titles_test = [titles[i] for i in train_index], [titles[i] for i in test_index]

    # Identify the columns (elements) that are present in the training data
    train_columns = X_train.columns[X_train.any() == 1]

    # Filter the test data to only include columns present in the training data
    X_train_filtered = X_train[train_columns]
    y_train_filtered = y_train[train_columns]
    X_test_filtered = X_test[train_columns]
    y_test_filtered = y_test[train_columns]

    # Initialize and train the classifier chain model with filtered data
    classifier_chain = ClassifierChain(base_classifier, order='random', random_state=42)
    classifier_chain.fit(X_train_filtered, y_train_filtered)

    # Predict on the filtered test set for this fold
    y_pred = classifier_chain.predict(X_test_filtered)

    # Print actual vs predicted compositions with titles for each object in the test set
    print("Title | Actual | Predicted")
    for title, actual, predicted in zip(titles_test, y_test_filtered.values, y_pred):
        actual_labels = ', '.join([col for col, val in zip(y.columns, actual) if val == 1])
        predicted_labels = ', '.join([col for col, val in zip(y.columns, predicted) if val == 1])
        print(f"{title} | Actual: {actual_labels} | Predicted: {predicted_labels}")

    # Calculate and print accuracy and classification report for this fold
    accuracy = accuracy_score(y_test_filtered, y_pred) * 100
    print(f"\nAccuracy for Fold {fold-1}: {accuracy:.2f}%")

    print("\nClassification Report for Fold:")
    print(classification_report(y_test_filtered, y_pred, target_names=train_columns, zero_division=0))
# Out:
# ============================== Fold 1 Results ==============================
# Title | Actual | Predicted
# paper-150 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-137 | Actual: Ti, Zr, Hf, Nb, Ta, Al | Predicted: Ti, Zr, Hf, Nb, Ta, Al
# paper-130 | Actual: Ti, Zr, Nb, Ta | Predicted: Ti, Zr, Nb, Ta
# paper-171 | Actual: N, I | Predicted: N, I
# paper-161 | Actual: F, C, I, B, Y | Predicted: F, C, I, B, Y
# paper-1 | Actual: Co, Cr, Fe, Mn, Cu, Si | Predicted: Co, Cr, Fe, Mn, Cu, Si
# paper-33 | Actual: Co, Cr, Fe, Ni, Ti, Nb, Mo, Al, W, C | Predicted: Co, Cr, Fe, Ni, Ti, Nb, Mo, Al, W, C
# paper-129 | Actual: Ti, Zr, Nb, Ta | Predicted: Ti, Zr, Nb, Ta
# paper-134 | Actual: Co, Cr, Fe, Ni, Ti, Al | Predicted: Co, Cr, Fe, Ni, Ti, Al
#
# Accuracy for Fold 1: 100.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Co       1.00      1.00      1.00         4
#           Cr       1.00      1.00      1.00         4
#           Fe       1.00      1.00      1.00         4
#           Mn       1.00      1.00      1.00         2
#           Ni       1.00      1.00      1.00         3
#           Ga       0.00      0.00      0.00         0
#            S       0.00      0.00      0.00         0
#           Ti       1.00      1.00      1.00         5
#           Zr       1.00      1.00      1.00         3
#           Hf       1.00      1.00      1.00         1
#            V       0.00      0.00      0.00         0
#           Nb       1.00      1.00      1.00         4
#           Ta       1.00      1.00      1.00         3
#           Mo       1.00      1.00      1.00         1
#           Al       1.00      1.00      1.00         3
#            W       1.00      1.00      1.00         1
#           Cu       1.00      1.00      1.00         1
#           Mg       0.00      0.00      0.00         0
#           Si       1.00      1.00      1.00         1
#            F       1.00      1.00      1.00         1
#            C       1.00      1.00      1.00         2
#            N       1.00      1.00      1.00         1
#            I       1.00      1.00      1.00         2
#            B       1.00      1.00      1.00         1
#            P       0.00      0.00      0.00         0
#            K       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            Y       1.00      1.00      1.00         1
#            H       0.00      0.00      0.00         0
#
#    micro avg       1.00      1.00      1.00        48
#    macro avg       0.72      0.72      0.72        48
# weighted avg       1.00      1.00      1.00        48
#  samples avg       1.00      1.00      1.00        48
#
#
# ============================== Fold 2 Results ==============================
# Title | Actual | Predicted
# paper-151 | Actual:  | Predicted:
# paper-143 | Actual: Co, Cr, Fe, Mn, Ni, Ti | Predicted: Co, Cr, Fe, Mn, Ni, Ti
# paper-133 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-170 | Actual: S, P | Predicted: S, P
# paper-157 | Actual: K | Predicted: K
# paper-6 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-34 | Actual: Co, Cr, Fe, Ni, Ti, Nb, Mo, Al, W, C | Predicted: Co, Cr, Fe, Ni, Ti, Nb, Mo, Al, W, C
# paper-146 | Actual: Ti, Zr, Hf, Nb, Ta | Predicted: Ti, Zr, Hf, Nb, Ta
# paper-151 | Actual: Co, Cr, Fe, Ni, Ti, Al | Predicted: Co, Cr, Fe, Ni, Ti, Al
#
# Accuracy for Fold 2: 100.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Co       1.00      1.00      1.00         5
#           Cr       1.00      1.00      1.00         5
#           Fe       1.00      1.00      1.00         5
#           Mn       1.00      1.00      1.00         3
#           Ni       1.00      1.00      1.00         5
#           Ga       0.00      0.00      0.00         0
#            S       1.00      1.00      1.00         1
#           Ti       1.00      1.00      1.00         4
#           Zr       1.00      1.00      1.00         1
#           Hf       1.00      1.00      1.00         1
#            V       0.00      0.00      0.00         0
#           Nb       1.00      1.00      1.00         2
#           Ta       1.00      1.00      1.00         1
#           Mo       1.00      1.00      1.00         1
#           Al       1.00      1.00      1.00         2
#            W       1.00      1.00      1.00         1
#           Cu       0.00      0.00      0.00         0
#           Mg       0.00      0.00      0.00         0
#           Si       0.00      0.00      0.00         0
#            F       0.00      0.00      0.00         0
#            C       1.00      1.00      1.00         1
#            N       0.00      0.00      0.00         0
#            I       0.00      0.00      0.00         0
#            B       0.00      0.00      0.00         0
#            P       1.00      1.00      1.00         1
#            O       1.00      1.00      1.00         1
#            Y       0.00      0.00      0.00         0
#            H       0.00      0.00      0.00         0
#
#    micro avg       1.00      1.00      1.00        40
#    macro avg       0.61      0.61      0.61        40
# weighted avg       1.00      1.00      1.00        40
#  samples avg       0.89      0.89      0.89        40
#
#
# ============================== Fold 3 Results ==============================
# Title | Actual | Predicted
# paper-145 | Actual: Co, Cr, Fe, Mn, Ni, Ti | Predicted: Co, Cr, Fe, Mn, Ni, Ti
# paper-169 | Actual: S, C, N, I, P | Predicted: S, C, N, I, P, K
# paper-163 | Actual: S, C, B | Predicted: S, C, B
# paper-7 | Actual: Co, Cr, Fe, Ni, Ti, Al | Predicted: Co, Cr, Fe, Ni, Ti, Al
# paper-126 | Actual: Ti, Zr, Hf, Nb, Ta | Predicted: Ti, Zr, Hf, Nb, Ta
# paper-130 | Actual: Ti, Zr, Nb, Ta | Predicted: Ti, Zr, Nb, Ta
# paper-133 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-137 | Actual: Co, Cr, Fe, Ni, Al | Predicted: Co, Cr, Fe, Ni, Al
# paper-140 | Actual: Cr, Ti, Zr, Nb, Ta, Mo | Predicted: Cr, Ti, Zr, Nb, Ta, Mo
#
# Accuracy for Fold 3: 88.89%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Co       1.00      1.00      1.00         4
#           Cr       1.00      1.00      1.00         5
#           Fe       1.00      1.00      1.00         4
#           Mn       1.00      1.00      1.00         2
#           Ni       1.00      1.00      1.00         4
#           Ga       0.00      0.00      0.00         0
#            S       1.00      1.00      1.00         2
#           Ti       1.00      1.00      1.00         5
#           Zr       1.00      1.00      1.00         3
#           Hf       1.00      1.00      1.00         1
#            V       0.00      0.00      0.00         0
#           Nb       1.00      1.00      1.00         3
#           Ta       1.00      1.00      1.00         3
#           Mo       1.00      1.00      1.00         1
#           Al       1.00      1.00      1.00         2
#            W       0.00      0.00      0.00         0
#           Cu       0.00      0.00      0.00         0
#           Mg       0.00      0.00      0.00         0
#           Si       0.00      0.00      0.00         0
#            F       0.00      0.00      0.00         0
#            C       1.00      1.00      1.00         2
#            N       1.00      1.00      1.00         1
#            I       1.00      1.00      1.00         1
#            B       1.00      1.00      1.00         1
#            P       1.00      1.00      1.00         1
#            K       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            Y       0.00      0.00      0.00         0
#            H       0.00      0.00      0.00         0
#
#    micro avg       0.98      1.00      0.99        45
#    macro avg       0.62      0.62      0.62        45
# weighted avg       1.00      1.00      1.00        45
#  samples avg       0.98      1.00      0.99        45
#
#
# ============================== Fold 4 Results ==============================
# Title | Actual | Predicted
# paper-152 | Actual:  | Predicted:
# paper-144 | Actual: Ti, Zr, Hf, Ta, Mo | Predicted: Ti, Zr, Hf, Ta, Mo
# paper-131 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-172 | Actual: S, C, B | Predicted: S, C, B
# paper-4 | Actual: Co, Cr, Fe, Ni, Ti, Al | Predicted: Co, Cr, Fe, Ni, Ti, Al
# paper-25 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-131 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-132 | Actual: Co, Cr, Fe, Mn, Ni, Al, Cu | Predicted: Co, Cr, Fe, Mn, Ni, Al, Cu
# paper-139 | Actual: Ti, Zr, Hf, V, Nb, Ta | Predicted: Ti, Zr, Hf, V, Nb, Ta
#
# Accuracy for Fold 4: 100.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Co       1.00      1.00      1.00         5
#           Cr       1.00      1.00      1.00         5
#           Fe       1.00      1.00      1.00         5
#           Mn       1.00      1.00      1.00         4
#           Ni       1.00      1.00      1.00         5
#           Ga       0.00      0.00      0.00         0
#            S       1.00      1.00      1.00         1
#           Ti       1.00      1.00      1.00         3
#           Zr       1.00      1.00      1.00         2
#           Hf       1.00      1.00      1.00         2
#            V       1.00      1.00      1.00         1
#           Nb       1.00      1.00      1.00         1
#           Ta       1.00      1.00      1.00         2
#           Mo       1.00      1.00      1.00         1
#           Al       1.00      1.00      1.00         2
#            W       0.00      0.00      0.00         0
#           Cu       1.00      1.00      1.00         1
#           Mg       0.00      0.00      0.00         0
#           Si       0.00      0.00      0.00         0
#            F       0.00      0.00      0.00         0
#            C       1.00      1.00      1.00         1
#            N       0.00      0.00      0.00         0
#            I       0.00      0.00      0.00         0
#            B       1.00      1.00      1.00         1
#            P       0.00      0.00      0.00         0
#            K       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            Y       0.00      0.00      0.00         0
#            H       0.00      0.00      0.00         0
#
#    micro avg       1.00      1.00      1.00        42
#    macro avg       0.59      0.59      0.59        42
# weighted avg       1.00      1.00      1.00        42
#  samples avg       0.89      0.89      0.89        42
#
#
# ============================== Fold 5 Results ==============================
# Title | Actual | Predicted
# paper-138 | Actual: Cr, Ti, Zr, Nb, Ta, Mo | Predicted: Cr, Ti, Zr, Nb, Ta, Mo
# paper-128 | Actual: Co, Cr, Fe, Ni, Ti, Cu | Predicted: Co, Cr, Fe, Ni, Ti, Cu
# paper-166 | Actual: C, N | Predicted: C, N
# paper-165 | Actual: S, C, B | Predicted: S, C, B
# paper-159 | Actual: F, C, I, B, Y | Predicted: F, C, I, B, Y
# paper-22 | Actual: Co, Cr, Fe, Mn, Cu, Si | Predicted: Co, Cr, Fe, Mn, Cu, Si
# paper-31 | Actual: Co, Cr, Fe, Mn, Si | Predicted: Co, Cr, Fe, Mn, Si
# paper-143 | Actual: Zr, Hf, Nb | Predicted: Zr, Hf, Nb
# paper-149 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
#
# Accuracy for Fold 5: 100.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Co       1.00      1.00      1.00         4
#           Cr       1.00      1.00      1.00         5
#           Fe       1.00      1.00      1.00         4
#           Mn       1.00      1.00      1.00         3
#           Ni       1.00      1.00      1.00         2
#           Ga       0.00      0.00      0.00         0
#            S       1.00      1.00      1.00         1
#           Ti       1.00      1.00      1.00         2
#           Zr       1.00      1.00      1.00         2
#           Hf       1.00      1.00      1.00         1
#            V       0.00      0.00      0.00         0
#           Nb       1.00      1.00      1.00         2
#           Ta       1.00      1.00      1.00         1
#           Mo       1.00      1.00      1.00         1
#           Al       0.00      0.00      0.00         0
#            W       0.00      0.00      0.00         0
#           Cu       1.00      1.00      1.00         2
#           Mg       0.00      0.00      0.00         0
#           Si       1.00      1.00      1.00         2
#            F       1.00      1.00      1.00         1
#            C       1.00      1.00      1.00         3
#            N       1.00      1.00      1.00         1
#            I       1.00      1.00      1.00         1
#            B       1.00      1.00      1.00         2
#            P       0.00      0.00      0.00         0
#            K       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            Y       1.00      1.00      1.00         1
#
#    micro avg       1.00      1.00      1.00        41
#    macro avg       0.71      0.71      0.71        41
# weighted avg       1.00      1.00      1.00        41
#  samples avg       1.00      1.00      1.00        41
#
#
# ============================== Fold 6 Results ==============================
# Title | Actual | Predicted
# paper-153 | Actual:  | Predicted:
# paper-139 | Actual: Ti, Zr, Hf, V, Nb, Ta | Predicted: Ti, Zr, Hf, V, Nb, Ta
# paper-141 | Actual: Co, Cr, Fe, Mn, Ni, Ti | Predicted: Co, Cr, Fe, Mn, Ni, Ti
# paper-142 | Actual: Co, Cr, Fe, Mn, Ni, Ti | Predicted: Co, Cr, Fe, Mn, Ni, Ti
# paper-132 | Actual: Co, Cr, Fe, Mn, Ni, Al, Cu | Predicted: Co, Cr, Fe, Mn, Ni, Al, Cu
# paper-168 | Actual: Al, Mg, Si, F | Predicted: Al, Mg, Si, F
# paper-162 | Actual: N, I | Predicted: N, I
# paper-128 | Actual: Co, Cr, Fe, Ni, Ti, Cu | Predicted: Co, Cr, Fe, Ni, Ti, Cu
# paper-152 | Actual: Co, Cr, Fe, Ni, Ti, Al | Predicted: Co, Cr, Fe, Ni, Ti, Al
#
# Accuracy for Fold 6: 100.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Co       1.00      1.00      1.00         5
#           Cr       1.00      1.00      1.00         5
#           Fe       1.00      1.00      1.00         5
#           Mn       1.00      1.00      1.00         3
#           Ni       1.00      1.00      1.00         5
#           Ga       0.00      0.00      0.00         0
#            S       0.00      0.00      0.00         0
#           Ti       1.00      1.00      1.00         5
#           Zr       1.00      1.00      1.00         1
#           Hf       1.00      1.00      1.00         1
#            V       1.00      1.00      1.00         1
#           Nb       1.00      1.00      1.00         1
#           Ta       1.00      1.00      1.00         1
#           Mo       0.00      0.00      0.00         0
#           Al       1.00      1.00      1.00         3
#            W       0.00      0.00      0.00         0
#           Cu       1.00      1.00      1.00         2
#           Mg       1.00      1.00      1.00         1
#           Si       1.00      1.00      1.00         1
#            F       1.00      1.00      1.00         1
#            C       0.00      0.00      0.00         0
#            N       1.00      1.00      1.00         1
#            I       1.00      1.00      1.00         1
#            B       0.00      0.00      0.00         0
#            P       0.00      0.00      0.00         0
#            K       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            Y       0.00      0.00      0.00         0
#            H       0.00      0.00      0.00         0
#
#    micro avg       1.00      1.00      1.00        43
#    macro avg       0.62      0.62      0.62        43
# weighted avg       1.00      1.00      1.00        43
#  samples avg       0.89      0.89      0.89        43
#
#
# ============================== Fold 7 Results ==============================
# Title | Actual | Predicted
# paper-164 | Actual: S, C, B | Predicted: S, C, B
# paper-5 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-23 | Actual: Co, Cr, Fe, Mn, Cu, Si | Predicted: Co, Cr, Fe, Mn, Cu, Si
# paper-8 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-32 | Actual: Co, Cr, Fe, Ni, Ti, Nb, Mo, Al, W, C | Predicted: Co, Cr, Fe, Ni, Ti, Nb, Mo, Al, W, C
# paper-95 | Actual: Mg, I | Predicted: Mg, I
# paper-145 | Actual: Ti, Zr, Hf, Nb, Ta, Al | Predicted: Ti, Zr, Hf, Nb, Ta, Al
# paper-153 | Actual: Co, Cr, Fe, Ni, Ti, Al | Predicted: Co, Cr, Fe, Ni, Ti, Al
# paper-154 | Actual: Ti, Zr, Hf, Ta, Mo, N | Predicted: Ti, Zr, Hf, Ta, Mo, N
#
# Accuracy for Fold 7: 100.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Co       1.00      1.00      1.00         5
#           Cr       1.00      1.00      1.00         5
#           Fe       1.00      1.00      1.00         5
#           Mn       1.00      1.00      1.00         3
#           Ni       1.00      1.00      1.00         4
#           Ga       0.00      0.00      0.00         0
#            S       1.00      1.00      1.00         1
#           Ti       1.00      1.00      1.00         4
#           Zr       1.00      1.00      1.00         2
#           Hf       1.00      1.00      1.00         2
#            V       0.00      0.00      0.00         0
#           Nb       1.00      1.00      1.00         2
#           Ta       1.00      1.00      1.00         2
#           Mo       1.00      1.00      1.00         2
#           Al       1.00      1.00      1.00         3
#            W       1.00      1.00      1.00         1
#           Cu       1.00      1.00      1.00         1
#           Mg       1.00      1.00      1.00         1
#           Si       1.00      1.00      1.00         1
#            F       0.00      0.00      0.00         0
#            C       1.00      1.00      1.00         2
#            N       1.00      1.00      1.00         1
#            I       1.00      1.00      1.00         1
#            B       1.00      1.00      1.00         1
#            P       0.00      0.00      0.00         0
#            K       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            Y       0.00      0.00      0.00         0
#            H       0.00      0.00      0.00         0
#
#    micro avg       1.00      1.00      1.00        49
#    macro avg       0.72      0.72      0.72        49
# weighted avg       1.00      1.00      1.00        49
#  samples avg       1.00      1.00      1.00        49
#
#
# ============================== Fold 8 Results ==============================
# Title | Actual | Predicted
# paper-136 | Actual: Ti, V, Nb, Ta, Mo, W | Predicted: Ti, V, Nb, Ta, Mo, W
# paper-173 | Actual: F, N, O | Predicted: F, N, O
# paper-2 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-26 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-95 | Actual: Mg, I | Predicted: Mg, I
# paper-110 | Actual: Al, Mg, Si | Predicted: Al, Mg, Si
# paper-136 | Actual: Co, Cr, Fe, Mn, Ni, Ti | Predicted: Co, Cr, Fe, Mn, Ni, Ti
# paper-144 | Actual: Ti, Zr, Hf, Ta, Mo, N | Predicted: Ti, Zr, Hf, Ta, Mo, N
# paper-150 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
#
# Accuracy for Fold 8: 100.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Co       1.00      1.00      1.00         4
#           Cr       1.00      1.00      1.00         4
#           Fe       1.00      1.00      1.00         4
#           Mn       1.00      1.00      1.00         4
#           Ni       1.00      1.00      1.00         4
#           Ga       0.00      0.00      0.00         0
#            S       0.00      0.00      0.00         0
#           Ti       1.00      1.00      1.00         3
#           Zr       1.00      1.00      1.00         1
#           Hf       1.00      1.00      1.00         1
#            V       1.00      1.00      1.00         1
#           Nb       1.00      1.00      1.00         1
#           Ta       1.00      1.00      1.00         2
#           Mo       1.00      1.00      1.00         2
#           Al       1.00      1.00      1.00         1
#            W       1.00      1.00      1.00         1
#           Cu       0.00      0.00      0.00         0
#           Mg       1.00      1.00      1.00         2
#           Si       1.00      1.00      1.00         1
#            F       1.00      1.00      1.00         1
#            C       0.00      0.00      0.00         0
#            N       1.00      1.00      1.00         2
#            I       1.00      1.00      1.00         1
#            B       0.00      0.00      0.00         0
#            P       0.00      0.00      0.00         0
#            K       0.00      0.00      0.00         0
#            O       1.00      1.00      1.00         1
#            Y       0.00      0.00      0.00         0
#            H       0.00      0.00      0.00         0
#
#    micro avg       1.00      1.00      1.00        41
#    macro avg       0.69      0.69      0.69        41
# weighted avg       1.00      1.00      1.00        41
#  samples avg       1.00      1.00      1.00        41
#
#
# ============================== Fold 9 Results ==============================
# Title | Actual | Predicted
# paper-148 | Actual: Co, Fe, Mn, Ni, Ga | Predicted: Co, Fe, Mn, Ni, Ga
# paper-155 | Actual: S | Predicted: S
# paper-129 | Actual: Ti, Zr, Nb, Ta | Predicted: Ti, Zr, Nb, Ta
# paper-174 | Actual: S, C, B | Predicted: S, C, B
# paper-160 | Actual: F, C, I, B, Y | Predicted: F, C, I, B, Y
# paper-51 | Actual: C, N, I | Predicted: C, N, I
# paper-109 | Actual: Mg, C | Predicted: Mg, C
# paper-127 | Actual: Co, Cr, Fe, Ni, Ti, Cu | Predicted: Co, Cr, Fe, Ni, Ti, Cu
# paper-141 | Actual: Co, Cr, Fe, Mn, Ni, Ti | Predicted: Co, Cr, Fe, Mn, Ni, Ti
#
# Accuracy for Fold 9: 100.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Co       1.00      1.00      1.00         3
#           Cr       1.00      1.00      1.00         2
#           Fe       1.00      1.00      1.00         3
#           Mn       1.00      1.00      1.00         2
#           Ni       1.00      1.00      1.00         3
#           Ga       1.00      1.00      1.00         1
#            S       1.00      1.00      1.00         2
#           Ti       1.00      1.00      1.00         3
#           Zr       1.00      1.00      1.00         1
#           Hf       0.00      0.00      0.00         0
#            V       0.00      0.00      0.00         0
#           Nb       1.00      1.00      1.00         1
#           Ta       1.00      1.00      1.00         1
#           Mo       0.00      0.00      0.00         0
#           Al       0.00      0.00      0.00         0
#            W       0.00      0.00      0.00         0
#           Cu       1.00      1.00      1.00         1
#           Mg       1.00      1.00      1.00         1
#           Si       0.00      0.00      0.00         0
#            F       1.00      1.00      1.00         1
#            C       1.00      1.00      1.00         4
#            N       1.00      1.00      1.00         1
#            I       1.00      1.00      1.00         2
#            B       1.00      1.00      1.00         2
#            P       0.00      0.00      0.00         0
#            K       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            Y       1.00      1.00      1.00         1
#            H       0.00      0.00      0.00         0
#
#    micro avg       1.00      1.00      1.00        35
#    macro avg       0.66      0.66      0.66        35
# weighted avg       1.00      1.00      1.00        35
#  samples avg       1.00      1.00      1.00        35
#
#
# ============================== Fold 10 Results ==============================
# Title | Actual | Predicted
# paper-135 | Actual: Co, Cr, Fe, Mn, Ni, Ti | Predicted: Co, Cr, Fe, Mn, Ni, Ti
# paper-127 | Actual: Co, Cr, Fe, Ni, Ti, Cu | Predicted: Co, Cr, Fe, Ni, Ti, Cu
# paper-126 | Actual: Ti, Zr, Hf, Nb, Ta | Predicted: Ti, Zr, Hf, Nb, Ta
# paper-27 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-104 | Actual: Fe, Al, Cu | Predicted: Al, Cu
# paper-135 | Actual: Ti, V, Nb, Ta, Mo, W | Predicted: Ti, V, Nb, Ta, Mo, W
# paper-138 | Actual: Cr, Ti, Zr, Nb, Ta, Mo | Predicted: Cr, Ti, Zr, Nb, Ta, Mo
# paper-147 | Actual: Co, Cr, Fe, Ni, Al, Cu | Predicted: Co, Cr, Fe, Ni, Al, Cu
# paper-148 | Actual: Co, Fe, Mn, Ni, Ga | Predicted: Co, Fe, Mn, Ni, Ga
#
# Accuracy for Fold 10: 88.89%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Co       1.00      1.00      1.00         5
#           Cr       1.00      1.00      1.00         5
#           Fe       1.00      0.83      0.91         6
#           Mn       1.00      1.00      1.00         3
#           Ni       1.00      1.00      1.00         5
#           Ga       1.00      1.00      1.00         1
#            S       0.00      0.00      0.00         0
#           Ti       1.00      1.00      1.00         5
#           Zr       1.00      1.00      1.00         2
#           Hf       1.00      1.00      1.00         1
#            V       1.00      1.00      1.00         1
#           Nb       1.00      1.00      1.00         3
#           Ta       1.00      1.00      1.00         3
#           Mo       1.00      1.00      1.00         2
#           Al       1.00      1.00      1.00         2
#            W       1.00      1.00      1.00         1
#           Cu       1.00      1.00      1.00         3
#           Mg       0.00      0.00      0.00         0
#           Si       0.00      0.00      0.00         0
#            F       0.00      0.00      0.00         0
#            C       0.00      0.00      0.00         0
#            N       0.00      0.00      0.00         0
#            I       0.00      0.00      0.00         0
#            B       0.00      0.00      0.00         0
#            P       0.00      0.00      0.00         0
#            K       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            Y       0.00      0.00      0.00         0
#            H       0.00      0.00      0.00         0
#
#    micro avg       1.00      0.98      0.99        48
#    macro avg       0.55      0.55      0.55        48
# weighted avg       1.00      0.98      0.99        48
#  samples avg       1.00      0.96      0.98        48

# %% [markdown]
# # 02/04/2025

# %%
import json
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.multioutput import ClassifierChain
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
import numpy as np

# List of valid chemical elements (symbols) in the periodic table
# Removed radioactive elements and noble gases.
periodic_elements = {
    "H", "Li", "Be", "B", "C", "N", "O", "F", "Na", "Mg", "Al", "Si", "P", "S", "Cl", "K", "Ca",
    "Sc", "Ti", "V", "Cr", "Mn", "Fe", "Co", "Ni", "Cu", "Zn", "Ga", "Ge", "As", "Se", "Br", "Rb", "Sr", "Y",
    "Zr", "Nb", "Mo", "Ru", "Rh", "Pd", "Ag", "Cd", "In", "Sn", "Sb", "Te", "I", "Cs", "Ba", "La", "Ce", "Pr",
    "Nd", "Sm", "Eu", "Gd", "Tb", "Dy", "Ho", "Er", "Tm", "Yb", "Lu", "Hf", "Ta", "W", "Re", "Os", "Ir", "Pt",
    "Au", "Hg", "Tl", "Pb", "Bi"
}

# Load the data
with open('admin.materials_100.json') as f:
    data = json.load(f)

# Extracting composition data and converting to DataFrame
compositions = []
titles = []

for entry in data:
    # Check if 'composition' exists and is not None
    if not entry.get('composition'):
        # print(f"Skipping entry with title '{entry.get('title', 'Unknown Title')}' due to missing 'composition'")
        continue
    # Set each element to 1 if it is present and it's a valid element, otherwise skip it
    composition = {element: 1 for element in entry['composition'].keys() if element in periodic_elements}
    titles.append(entry['title'])
    compositions.append(composition)

# Convert compositions to DataFrame
df = pd.DataFrame(compositions)
df.fillna(0, inplace=True)  # Fill NaN with 0 for elements not present

# Define features (X) and binary label columns (y)
X = df.copy()  # Features
y = df.copy()  # Multi-label targets, each element is its own label

# Initialize the base classifier
base_classifier = DecisionTreeClassifier(random_state=42)

# Set up K-fold cross-validation
kf = KFold(n_splits=10, shuffle=True, random_state=42)
fold = 1

# Loop over each fold
for train_index, test_index in kf.split(X):
    print(f"\n{'='*30} Fold {fold} Results {'='*30}")
    fold += 1

    # Split data into train and test sets for this fold
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    titles_train, titles_test = [titles[i] for i in train_index], [titles[i] for i in test_index]

    # Identify the columns (elements) that are present in the training data
    train_columns = X_train.columns[X_train.any() == 1]

    # Filter the test data to only include columns present in the training data
    X_train_filtered = X_train[train_columns]
    y_train_filtered = y_train[train_columns]
    X_test_filtered = X_test[train_columns]
    y_test_filtered = y_test[train_columns]

    # Initialize and train the classifier chain model with filtered data
    classifier_chain = ClassifierChain(base_classifier, order='random', random_state=42)
    classifier_chain.fit(X_train_filtered, y_train_filtered)

    # Predict on the filtered test set for this fold
    y_pred = classifier_chain.predict(X_test_filtered)

    # Print actual vs predicted compositions with titles for each object in the test set
    print("Title | Actual | Predicted")
    for title, actual, predicted in zip(titles_test, y_test_filtered.values, y_pred):
        actual_labels = ', '.join([col for col, val in zip(y.columns, actual) if val == 1])
        predicted_labels = ', '.join([col for col, val in zip(y.columns, predicted) if val == 1])
        print(f"{title} | Actual: {actual_labels} | Predicted: {predicted_labels}")

    # Calculate and print accuracy and classification report for this fold
    accuracy = accuracy_score(y_test_filtered, y_pred) * 100
    print(f"\nAccuracy for Fold {fold-1}: {accuracy:.2f}%")

    print("\nClassification Report for Fold:")
    print(classification_report(y_test_filtered, y_pred, target_names=train_columns, zero_division=0))
# Out:
# ============================== Fold 1 Results ==============================
# Title | Actual | Predicted
# paper-150 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-133 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-1 | Actual: Co, Cr, Fe, Mn, Cu, Si | Predicted: Co, Cr, Fe, Mn, Cu, Si
# paper-110 | Actual: Al, Si, Mg | Predicted: Al, Si, Mg
# paper-131 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-133 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-144 | Actual: Ti, Zr, Hf, Ta, Mo, N | Predicted: Ti, Zr, Hf, Ta, Mo, N
# paper-210 | Actual: Nb, Ta, Mo, C, W | Predicted: Nb, Ta, Mo, C, W
# paper-218 | Actual: Co, Cr, Fe, Ni, Al, Cu | Predicted: Co, Cr, Fe, Ni, Al, Cu
# paper-229 | Actual: Ti, Zr, V, Nb, Al | Predicted: Ti, Zr, V, Nb, Al
#
# Accuracy for Fold 1: 100.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Co       1.00      1.00      1.00         6
#           Cr       1.00      1.00      1.00         6
#           Fe       1.00      1.00      1.00         6
#           Mn       1.00      1.00      1.00         5
#           Ni       1.00      1.00      1.00         5
#           Ti       1.00      1.00      1.00         2
#           Zr       1.00      1.00      1.00         2
#           Hf       1.00      1.00      1.00         1
#            V       1.00      1.00      1.00         1
#           Nb       1.00      1.00      1.00         2
#           Ta       1.00      1.00      1.00         2
#           Mo       1.00      1.00      1.00         2
#           Al       1.00      1.00      1.00         3
#           Cu       1.00      1.00      1.00         2
#            C       1.00      1.00      1.00         1
#            N       1.00      1.00      1.00         1
#            I       0.00      0.00      0.00         0
#            B       0.00      0.00      0.00         0
#            S       0.00      0.00      0.00         0
#            P       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            F       0.00      0.00      0.00         0
#           Si       1.00      1.00      1.00         2
#            H       0.00      0.00      0.00         0
#            W       1.00      1.00      1.00         1
#           Mg       1.00      1.00      1.00         1
#
#    micro avg       1.00      1.00      1.00        51
#    macro avg       0.73      0.73      0.73        51
# weighted avg       1.00      1.00      1.00        51
#  samples avg       1.00      1.00      1.00        51
#
#
# ============================== Fold 2 Results ==============================
# Title | Actual | Predicted
# paper-139 | Actual: Ti, Zr, Hf, V, Nb, Ta | Predicted: Ti, Zr, Hf, V, Nb, Ta
# paper-127 | Actual: Co, Cr, Fe, Ni, Ti, Cu | Predicted: Co, Cr, Fe, Ni, Ti, Cu
# paper-173 | Actual: N, O | Predicted: N, O
# paper-26 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-7 | Actual: Co, Cr, Fe, Ni, Ti, Al | Predicted: Co, Cr, Fe, Ni, Ti, Al
# paper-27 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-213 | Actual: Co, Cr, Fe, Mn | Predicted: Co, Cr, Fe, Mn
# paper-226 | Actual: Co, Cr, Fe, Mn, Ni, Al | Predicted: Co, Cr, Fe, Mn, Ni, Al
# paper-227 | Actual: Co, Cr, Fe, Mn, Ni, Al | Predicted: Co, Cr, Fe, Mn, Ni, Al
# paper-232 | Actual: Co, Cr, Fe, Ni, Al | Predicted: Co, Cr, Fe, Ni, Al
#
# Accuracy for Fold 2: 100.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Co       1.00      1.00      1.00         8
#           Cr       1.00      1.00      1.00         8
#           Fe       1.00      1.00      1.00         8
#           Mn       1.00      1.00      1.00         5
#           Ni       1.00      1.00      1.00         7
#           Ti       1.00      1.00      1.00         3
#           Zr       1.00      1.00      1.00         1
#           Hf       1.00      1.00      1.00         1
#            V       1.00      1.00      1.00         1
#           Nb       1.00      1.00      1.00         1
#           Ta       1.00      1.00      1.00         1
#           Mo       0.00      0.00      0.00         0
#           Al       1.00      1.00      1.00         4
#           Cu       1.00      1.00      1.00         1
#            C       0.00      0.00      0.00         0
#            N       1.00      1.00      1.00         1
#            I       0.00      0.00      0.00         0
#            B       0.00      0.00      0.00         0
#            S       0.00      0.00      0.00         0
#            P       0.00      0.00      0.00         0
#            O       1.00      1.00      1.00         1
#           Si       0.00      0.00      0.00         0
#            H       0.00      0.00      0.00         0
#            W       0.00      0.00      0.00         0
#           Mg       0.00      0.00      0.00         0
#
#    micro avg       1.00      1.00      1.00        51
#    macro avg       0.60      0.60      0.60        51
# weighted avg       1.00      1.00      1.00        51
#  samples avg       1.00      1.00      1.00        51
#
#
# ============================== Fold 3 Results ==============================
# Title | Actual | Predicted
# paper-131 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-171 | Actual: N, I | Predicted: N, I
# paper-6 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-109 | Actual: C, Mg | Predicted: C, Mg
# paper-128 | Actual: Co, Cr, Fe, Ni, Ti, Cu | Predicted: Co, Cr, Fe, Ni, Ti, Cu
# paper-146 | Actual: Ti, Zr, Hf, Nb, Ta | Predicted: Ti, Zr, Hf, Nb, Ta
# paper-208 | Actual: Cr, Fe, Mn, Ni, V | Predicted: Cr, Fe, Mn, Ni, V
# paper-212 | Actual: Nb, Ta, Mo, C, W | Predicted: Nb, Ta, Mo, C, W
# paper-223 | Actual: Cr, Fe, Ni, Ti, Al, Cu, Si | Predicted: Cr, Fe, Ni, Ti, Al, Cu, Si
# paper-238 | Actual: Co, Mn, Ni, Al, Cu | Predicted: Co, Mn, Ni, Al, Cu
#
# Accuracy for Fold 3: 100.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Co       1.00      1.00      1.00         4
#           Cr       1.00      1.00      1.00         5
#           Fe       1.00      1.00      1.00         5
#           Mn       1.00      1.00      1.00         4
#           Ni       1.00      1.00      1.00         6
#           Ti       1.00      1.00      1.00         3
#           Zr       1.00      1.00      1.00         1
#           Hf       1.00      1.00      1.00         1
#            V       1.00      1.00      1.00         1
#           Nb       1.00      1.00      1.00         2
#           Ta       1.00      1.00      1.00         2
#           Mo       1.00      1.00      1.00         1
#           Al       1.00      1.00      1.00         2
#           Cu       1.00      1.00      1.00         3
#            C       1.00      1.00      1.00         2
#            N       1.00      1.00      1.00         1
#            I       1.00      1.00      1.00         1
#            B       0.00      0.00      0.00         0
#            S       0.00      0.00      0.00         0
#            P       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            F       0.00      0.00      0.00         0
#           Si       1.00      1.00      1.00         1
#            H       0.00      0.00      0.00         0
#            W       1.00      1.00      1.00         1
#           Mg       1.00      1.00      1.00         1
#
#    micro avg       1.00      1.00      1.00        47
#    macro avg       0.77      0.77      0.77        47
# weighted avg       1.00      1.00      1.00        47
#  samples avg       1.00      1.00      1.00        47
#
#
# ============================== Fold 4 Results ==============================
# Title | Actual | Predicted
# paper-138 | Actual: Cr, Ti, Zr, Nb, Ta, Mo | Predicted: Cr, Ti, Zr, Nb, Ta, Mo
# paper-128 | Actual: Co, Cr, Fe, Ni, Ti, Cu | Predicted: Co, Cr, Fe, Ni, Ti, Cu
# paper-174 | Actual: C, B, S | Predicted: C, B, S
# paper-23 | Actual: Co, Cr, Fe, Mn, Cu, Si | Predicted: Co, Cr, Fe, Mn, Cu, Si
# paper-31 | Actual: Co, Cr, Fe, Mn, Si | Predicted: Co, Cr, Fe, Mn, Si
# paper-137 | Actual: Co, Cr, Fe, Ni, Al | Predicted: Co, Cr, Fe, Ni, Al
# paper-205 | Actual: Co, Cr, Ni, Ti, Al | Predicted: Co, Cr, Ni, Ti, Al
# paper-203 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-219 | Actual: Co, Cr, Fe, Ni, Al | Predicted: Co, Cr, Fe, Ni, Al
# paper-235 | Actual: C | Predicted: C
#
# Accuracy for Fold 4: 100.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Co       1.00      1.00      1.00         7
#           Cr       1.00      1.00      1.00         8
#           Fe       1.00      1.00      1.00         6
#           Mn       1.00      1.00      1.00         3
#           Ni       1.00      1.00      1.00         5
#           Ti       1.00      1.00      1.00         3
#           Zr       1.00      1.00      1.00         1
#           Hf       0.00      0.00      0.00         0
#            V       0.00      0.00      0.00         0
#           Nb       1.00      1.00      1.00         1
#           Ta       1.00      1.00      1.00         1
#           Mo       1.00      1.00      1.00         1
#           Al       1.00      1.00      1.00         3
#           Cu       1.00      1.00      1.00         2
#            C       1.00      1.00      1.00         2
#            N       0.00      0.00      0.00         0
#            I       0.00      0.00      0.00         0
#            B       1.00      1.00      1.00         1
#            S       1.00      1.00      1.00         1
#            P       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            F       0.00      0.00      0.00         0
#           Si       1.00      1.00      1.00         2
#            W       0.00      0.00      0.00         0
#           Mg       0.00      0.00      0.00         0
#
#    micro avg       1.00      1.00      1.00        47
#    macro avg       0.64      0.64      0.64        47
# weighted avg       1.00      1.00      1.00        47
#  samples avg       1.00      1.00      1.00        47
#
#
# ============================== Fold 5 Results ==============================
# Title | Actual | Predicted
# paper-144 | Actual: Ti, Zr, Hf, Ta, Mo | Predicted: Ti, Zr, Hf, Ta, Mo
# paper-129 | Actual: Ti, Zr, Nb, Ta | Predicted: Ti, Zr, Nb, Ta
# paper-163 | Actual: C, B, S | Predicted: C, B, S
# paper-5 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-22 | Actual: Co, Cr, Fe, Mn, Cu, Si | Predicted: Co, Cr, Fe, Mn, Cu, Si
# paper-51 | Actual: C, N, I | Predicted: C, N, I
# paper-139 | Actual: Ti, Zr, Hf, V, Nb, Ta | Predicted: Ti, Zr, Hf, V, Nb, Ta
# paper-202 | Actual: Co, Cr, Fe, Ni, Al, Cu | Predicted: Co, Cr, Fe, Ni, Al, Cu
# paper-217 | Actual: Cr, Fe, Mn, Ni, Cu, C | Predicted: Cr, Fe, Mn, Ni, Cu, C
# paper-237 | Actual: Ti, Zr, V, Nb | Predicted: Ti, Zr, V, Nb
#
# Accuracy for Fold 5: 100.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Co       1.00      1.00      1.00         3
#           Cr       1.00      1.00      1.00         4
#           Fe       1.00      1.00      1.00         4
#           Mn       1.00      1.00      1.00         3
#           Ni       1.00      1.00      1.00         3
#           Ti       1.00      1.00      1.00         4
#           Zr       1.00      1.00      1.00         4
#           Hf       1.00      1.00      1.00         2
#            V       1.00      1.00      1.00         2
#           Nb       1.00      1.00      1.00         3
#           Ta       1.00      1.00      1.00         3
#           Mo       1.00      1.00      1.00         1
#           Al       1.00      1.00      1.00         1
#           Cu       1.00      1.00      1.00         3
#            C       1.00      1.00      1.00         3
#            N       1.00      1.00      1.00         1
#            I       1.00      1.00      1.00         1
#            B       1.00      1.00      1.00         1
#            S       1.00      1.00      1.00         1
#            P       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            F       0.00      0.00      0.00         0
#           Si       1.00      1.00      1.00         1
#            H       0.00      0.00      0.00         0
#            W       0.00      0.00      0.00         0
#           Mg       0.00      0.00      0.00         0
#
#    micro avg       1.00      1.00      1.00        48
#    macro avg       0.77      0.77      0.77        48
# weighted avg       1.00      1.00      1.00        48
#  samples avg       1.00      1.00      1.00        48
#
#
# ============================== Fold 6 Results ==============================
# Title | Actual | Predicted
# paper-152 | Actual:  | Predicted:
# paper-141 | Actual: Co, Cr, Fe, Mn, Ni, Ti | Predicted: Co, Cr, Fe, Mn, Ni, Ti
# paper-137 | Actual: Ti, Zr, Hf, Nb, Ta, Al | Predicted: Ti, Zr, Hf, Nb, Ta, Al
# paper-169 | Actual: C, N, I, S | Predicted: C, N, I, B
# paper-4 | Actual: Co, Cr, Fe, Ni, Ti, Al | Predicted: Co, Cr, Fe, Ni, Ti, Al
# paper-32 | Actual: Co, Cr, Fe, Ni, Ti, Nb, Mo, Al, C, H | Predicted: Co, Cr, Fe, Ni, Ti, Nb, Mo, Al, C, H
# paper-34 | Actual: Co, Cr, Fe, Ni, Ti, Nb, Mo, Al, C, H | Predicted: Co, Cr, Fe, Ni, Ti, Nb, Mo, Al, C, H
# paper-206 | Actual: Co, Cr, Ni, Ti, Al | Predicted: Co, Cr, Ni, Ti, Al
# paper-228 | Actual: Cr, Ti, Zr, V, Mo, Al | Predicted: Cr, Ti, Zr, V, Mo, Al
# paper-224 | Actual: Ti, Zr, Nb, Ta, Al | Predicted: Ti, Zr, Nb, Ta, Al
#
# Accuracy for Fold 6: 90.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Co       1.00      1.00      1.00         5
#           Cr       1.00      1.00      1.00         6
#           Fe       1.00      1.00      1.00         4
#           Mn       1.00      1.00      1.00         1
#           Ni       1.00      1.00      1.00         5
#           Ti       1.00      1.00      1.00         8
#           Zr       1.00      1.00      1.00         3
#           Hf       1.00      1.00      1.00         1
#            V       1.00      1.00      1.00         1
#           Nb       1.00      1.00      1.00         4
#           Ta       1.00      1.00      1.00         2
#           Mo       1.00      1.00      1.00         3
#           Al       1.00      1.00      1.00         7
#           Cu       0.00      0.00      0.00         0
#            C       1.00      1.00      1.00         3
#            N       1.00      1.00      1.00         1
#            I       1.00      1.00      1.00         1
#            B       0.00      0.00      0.00         0
#            S       0.00      0.00      0.00         1
#            O       0.00      0.00      0.00         0
#            F       0.00      0.00      0.00         0
#           Si       0.00      0.00      0.00         0
#            H       0.00      0.00      0.00         0
#            W       1.00      1.00      1.00         2
#           Mg       0.00      0.00      0.00         0
#
#    micro avg       0.98      0.98      0.98        58
#    macro avg       0.68      0.68      0.68        58
# weighted avg       0.98      0.98      0.98        58
#  samples avg       0.88      0.88      0.88        58
#
#
# ============================== Fold 7 Results ==============================
# Title | Actual | Predicted
# paper-129 | Actual: Ti, Zr, Nb, Ta | Predicted: Ti, Zr, Nb, Ta
# paper-134 | Actual: Co, Cr, Fe, Ni, Ti, Al | Predicted: Co, Cr, Fe, Ni, Ti, Al
# paper-140 | Actual: Cr, Ti, Zr, Nb, Ta, Mo | Predicted: Cr, Ti, Zr, Nb, Ta, Mo
# paper-145 | Actual: Ti, Zr, Hf, Nb, Ta, Al | Predicted: Ti, Zr, Hf, Nb, Ta, Al
# paper-150 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-201 | Actual: Co, Cr, Fe, Ni, Ti, Al | Predicted: Co, Cr, Fe, Ni, Ti, Al
# paper-209 | Actual: Cr, Fe, Mn, Ni, V | Predicted: Cr, Fe, Mn, Ni, V
# paper-207 | Actual: Cr, Fe, Mn, Ni, V | Predicted: Cr, Fe, Mn, Ni, V
# paper-239 | Actual: Cr, Fe, Ni, Al, Cu | Predicted: Cr, Fe, Ni, Al, Cu
# paper-242 | Actual: Co, Cr, Fe, Ni, Al | Predicted: Co, Cr, Fe, Ni, Al
#
# Accuracy for Fold 7: 100.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Co       1.00      1.00      1.00         4
#           Cr       1.00      1.00      1.00         8
#           Fe       1.00      1.00      1.00         7
#           Mn       1.00      1.00      1.00         3
#           Ni       1.00      1.00      1.00         7
#           Ti       1.00      1.00      1.00         5
#           Zr       1.00      1.00      1.00         3
#           Hf       1.00      1.00      1.00         1
#            V       1.00      1.00      1.00         2
#           Nb       1.00      1.00      1.00         3
#           Ta       1.00      1.00      1.00         3
#           Mo       1.00      1.00      1.00         1
#           Al       1.00      1.00      1.00         5
#           Cu       1.00      1.00      1.00         1
#            C       0.00      0.00      0.00         0
#            N       0.00      0.00      0.00         0
#            I       0.00      0.00      0.00         0
#            B       0.00      0.00      0.00         0
#            S       0.00      0.00      0.00         0
#            P       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            F       0.00      0.00      0.00         0
#           Si       0.00      0.00      0.00         0
#            H       0.00      0.00      0.00         0
#            W       0.00      0.00      0.00         0
#           Mg       0.00      0.00      0.00         0
#
#    micro avg       1.00      1.00      1.00        53
#    macro avg       0.54      0.54      0.54        53
# weighted avg       1.00      1.00      1.00        53
#  samples avg       1.00      1.00      1.00        53
#
#
# ============================== Fold 8 Results ==============================
# Title | Actual | Predicted
# paper-8 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-127 | Actual: Co, Cr, Fe, Ni, Ti, Cu | Predicted: Co, Cr, Fe, Ni, Ti, Cu
# paper-138 | Actual: Cr, Ti, Zr, Nb, Ta, Mo | Predicted: Cr, Ti, Zr, Nb, Ta, Mo
# paper-151 | Actual: Co, Cr, Fe, Ni, Ti, Al | Predicted: Co, Cr, Fe, Ni, Ti, Al
# paper-152 | Actual: Co, Cr, Fe, Ni, Ti, Al | Predicted: Co, Cr, Fe, Ni, Ti, Al
# paper-153 | Actual: Co, Cr, Fe, Ni, Ti, Al | Predicted: Co, Cr, Fe, Ni, Ti, Al
# paper-225 | Actual: Co, Cr, Fe, Mn, Ni, Al | Predicted: Co, Cr, Fe, Mn, Ni, Al
# paper-216 | Actual: Ti, Zr, V, Nb, Al | Predicted: Ti, Zr, V, Nb, Al
# paper-236 | Actual: Co, Cr, Fe, Ni, Al | Predicted: Co, Cr, Fe, Ni, Al
# paper-240 | Actual: Cr, V, Nb, Mo, Al | Predicted: Cr, V, Nb, Mo, Al
#
# Accuracy for Fold 8: 100.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Co       1.00      1.00      1.00         7
#           Cr       1.00      1.00      1.00         9
#           Fe       1.00      1.00      1.00         7
#           Mn       1.00      1.00      1.00         2
#           Ni       1.00      1.00      1.00         7
#           Ti       1.00      1.00      1.00         6
#           Zr       1.00      1.00      1.00         2
#           Hf       0.00      0.00      0.00         0
#            V       1.00      1.00      1.00         2
#           Nb       1.00      1.00      1.00         3
#           Ta       1.00      1.00      1.00         1
#           Mo       1.00      1.00      1.00         2
#           Al       1.00      1.00      1.00         7
#           Cu       1.00      1.00      1.00         1
#            C       0.00      0.00      0.00         0
#            N       0.00      0.00      0.00         0
#            I       0.00      0.00      0.00         0
#            B       0.00      0.00      0.00         0
#            S       0.00      0.00      0.00         0
#            P       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            F       0.00      0.00      0.00         0
#           Si       0.00      0.00      0.00         0
#            H       0.00      0.00      0.00         0
#            W       0.00      0.00      0.00         0
#           Mg       0.00      0.00      0.00         0
#
#    micro avg       1.00      1.00      1.00        56
#    macro avg       0.50      0.50      0.50        56
# weighted avg       1.00      1.00      1.00        56
#  samples avg       1.00      1.00      1.00        56
#
#
# ============================== Fold 9 Results ==============================
# Title | Actual | Predicted
# paper-153 | Actual:  | Predicted:
# paper-151 | Actual:  | Predicted:
# paper-162 | Actual: N, I | Predicted: N, I
# paper-2 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-25 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-33 | Actual: Co, Cr, Fe, Ni, Ti, Nb, Mo, Al, C, W | Predicted: Co, Cr, Fe, Ni, Ti, Nb, Mo, Al, C, W
# paper-143 | Actual: Zr, Hf, Nb | Predicted: Zr, Hf, Nb
# paper-204 | Actual: Co, Cr, Ni, Ti, Al | Predicted: Co, Cr, Ni, Ti, Al
# paper-230 | Actual: Co, Cr, Fe, Ni, Al, Cu | Predicted: Co, Cr, Fe, Ni, Al, Cu
# paper-222 | Actual: Co, Cr, Fe, Mn, Nb, C | Predicted: Co, Cr, Fe, Mn, Nb, C
#
# Accuracy for Fold 9: 100.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Co       1.00      1.00      1.00         6
#           Cr       1.00      1.00      1.00         6
#           Fe       1.00      1.00      1.00         5
#           Mn       1.00      1.00      1.00         3
#           Ni       1.00      1.00      1.00         5
#           Ti       1.00      1.00      1.00         2
#           Zr       1.00      1.00      1.00         1
#           Hf       1.00      1.00      1.00         1
#            V       0.00      0.00      0.00         0
#           Nb       1.00      1.00      1.00         3
#           Ta       0.00      0.00      0.00         0
#           Mo       1.00      1.00      1.00         1
#           Al       1.00      1.00      1.00         3
#           Cu       1.00      1.00      1.00         1
#            C       1.00      1.00      1.00         2
#            N       1.00      1.00      1.00         1
#            I       1.00      1.00      1.00         1
#            B       0.00      0.00      0.00         0
#            S       0.00      0.00      0.00         0
#            P       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            F       0.00      0.00      0.00         0
#           Si       0.00      0.00      0.00         0
#            H       0.00      0.00      0.00         0
#            W       1.00      1.00      1.00         1
#           Mg       0.00      0.00      0.00         0
#
#    micro avg       1.00      1.00      1.00        42
#    macro avg       0.62      0.62      0.62        42
# weighted avg       1.00      1.00      1.00        42
#  samples avg       0.80      0.80      0.80        42
#
#
# ============================== Fold 10 Results ==============================
# Title | Actual | Predicted
# paper-166 | Actual: C, N | Predicted: C, N
# paper-157 | Actual: O | Predicted: O, F
# paper-141 | Actual: Co, Cr, Fe, Mn, Ni, Ti | Predicted: Co, Cr, Fe, Mn, Ni, Ti
# paper-200 | Actual: Co, Cr, Fe, Ni, Ti, Al | Predicted: Co, Cr, Fe, Ni, Ti, Al
# paper-211 | Actual: Nb, Ta, Mo, C, W | Predicted: Nb, Ta, Mo, C, W
# paper-214 | Actual: Co, Cr, Fe, Mn, Ni, Al | Predicted: Co, Cr, Fe, Mn, Ni, Al
# paper-231 | Actual: Co, Cr, Fe, Ni, Al, Cu | Predicted: Co, Cr, Fe, Ni, Al, Cu
# paper-221 | Actual: Co, Cr, Fe, V, Al | Predicted: Co, Cr, Fe, V, Al
# paper-233 | Actual: Co, Cr, Fe, Ni, Al | Predicted: Co, Cr, Fe, Ni, Al
# paper-234 | Actual: Co, Cr, Fe, Ni, Al | Predicted: Co, Cr, Fe, Ni, Al
#
# Accuracy for Fold 10: 90.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Co       1.00      1.00      1.00         7
#           Cr       1.00      1.00      1.00         7
#           Fe       1.00      1.00      1.00         7
#           Mn       1.00      1.00      1.00         2
#           Ni       1.00      1.00      1.00         6
#           Ti       1.00      1.00      1.00         2
#           Zr       0.00      0.00      0.00         0
#           Hf       0.00      0.00      0.00         0
#            V       1.00      1.00      1.00         1
#           Nb       1.00      1.00      1.00         1
#           Ta       1.00      1.00      1.00         1
#           Mo       1.00      1.00      1.00         1
#           Al       1.00      1.00      1.00         6
#           Cu       1.00      1.00      1.00         1
#            C       1.00      1.00      1.00         2
#            N       1.00      1.00      1.00         1
#            I       0.00      0.00      0.00         0
#            B       0.00      0.00      0.00         0
#            S       0.00      0.00      0.00         0
#            P       0.00      0.00      0.00         0
#            O       1.00      1.00      1.00         1
#            F       0.00      0.00      0.00         0
#           Si       0.00      0.00      0.00         0
#            H       0.00      0.00      0.00         0
#            W       1.00      1.00      1.00         1
#           Mg       0.00      0.00      0.00         0
#
#    micro avg       0.98      1.00      0.99        47
#    macro avg       0.62      0.62      0.62        47
# weighted avg       1.00      1.00      1.00        47
#  samples avg       0.95      1.00      0.97        47

# %%
import json
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.multioutput import ClassifierChain
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt

# List of valid chemical elements (symbols) in the periodic table
periodic_elements = {
    "H", "Li", "Be", "B", "C", "N", "O", "F", "Na", "Mg", "Al", "Si", "P", "S", "Cl", "K", "Ca",
    "Sc", "Ti", "V", "Cr", "Mn", "Fe", "Co", "Ni", "Cu", "Zn", "Ga", "Ge", "As", "Se", "Br", "Rb", "Sr", "Y",
    "Zr", "Nb", "Mo", "Ru", "Rh", "Pd", "Ag", "Cd", "In", "Sn", "Sb", "Te", "I", "Cs", "Ba", "La", "Ce", "Pr",
    "Nd", "Sm", "Eu", "Gd", "Tb", "Dy", "Ho", "Er", "Tm", "Yb", "Lu", "Hf", "Ta", "W", "Re", "Os", "Ir", "Pt",
    "Au", "Hg", "Tl", "Pb", "Bi"
}

# Load the data
with open('admin.materials_100.json') as f:
    data = json.load(f)

# Extracting composition data and converting to DataFrame
compositions = []
titles = []

for entry in data:
    if not entry.get('composition'):
        continue
    composition = {element: 1 for element in entry['composition'].keys() if element in periodic_elements}
    titles.append(entry['title'])
    compositions.append(composition)

# Convert compositions to DataFrame
df = pd.DataFrame(compositions)
df.fillna(0, inplace=True)  # Fill NaN with 0 for elements not present

# Define features (X) and binary label columns (y)
X = df.copy()
y = df.copy()

# Initialize the base classifier
base_classifier = DecisionTreeClassifier(random_state=42)

# Set up K-fold cross-validation
kf = KFold(n_splits=10, shuffle=True, random_state=42)
fold = 1

for train_index, test_index in kf.split(X):
    print(f"\n{'='*30} Fold {fold} Results {'='*30}")
    fold += 1

    # Split data into train and test sets for this fold
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    titles_train, titles_test = [titles[i] for i in train_index], [titles[i] for i in test_index]

    # Identify the columns (elements) that are present in the training data
    train_columns = X_train.columns[X_train.any() == 1]

    # Filter the test data to only include columns present in the training data
    X_train_filtered = X_train[train_columns]
    y_train_filtered = y_train[train_columns]
    X_test_filtered = X_test[train_columns]
    y_test_filtered = y_test[train_columns]

    # Initialize and train the classifier chain model with filtered data
    classifier_chain = ClassifierChain(base_classifier, order='random', random_state=42)
    classifier_chain.fit(X_train_filtered, y_train_filtered)

    # Predict on the filtered test set for this fold
    y_pred = classifier_chain.predict(X_test_filtered)

    # Print actual vs predicted compositions with titles for each object in the test set
    print("Title | Actual | Predicted")
    for title, actual, predicted in zip(titles_test, y_test_filtered.values, y_pred):
        actual_labels = ', '.join([col for col, val in zip(y.columns, actual) if val == 1])
        predicted_labels = ', '.join([col for col, val in zip(y.columns, predicted) if val == 1])
        print(f"{title} | Actual: {actual_labels} | Predicted: {predicted_labels}")

    # Calculate and print accuracy and classification report for this fold
    accuracy = accuracy_score(y_test_filtered, y_pred) * 100
    print(f"\nAccuracy for Fold {fold-1}: {accuracy:.2f}%")

    print("\nClassification Report for Fold:")
    print(classification_report(y_test_filtered, y_pred, target_names=train_columns, zero_division=0))

    # Plot the decision tree without the value attribute
    plt.figure(figsize=(20, 10))
    plot_tree(
        classifier_chain.estimators_[0],  # Plot the first decision tree of the chain
        feature_names=X_train_filtered.columns,
        class_names=train_columns,
        filled=True,
        impurity=False,    # Remove impurity (like Gini or entropy)
        label='none'       # Remove 'value' and sample counts
    )
    plt.title(f"Decision Tree for Fold {fold-1}")
    plt.show()

    # Break after the first fold if you want to see just one tree
    break
# Out:
# ============================== Fold 1 Results ==============================
# Title | Actual | Predicted
# paper-150 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-133 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-1 | Actual: Co, Cr, Fe, Mn, Cu, Si | Predicted: Co, Cr, Fe, Mn, Cu, Si
# paper-110 | Actual: Al, Si, Mg | Predicted: Al, Si, Mg
# paper-131 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-133 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-144 | Actual: Ti, Zr, Hf, Ta, Mo, N | Predicted: Ti, Zr, Hf, Ta, Mo, N
# paper-210 | Actual: Nb, Ta, Mo, C, W | Predicted: Nb, Ta, Mo, C, W
# paper-218 | Actual: Co, Cr, Fe, Ni, Al, Cu | Predicted: Co, Cr, Fe, Ni, Al, Cu
# paper-229 | Actual: Ti, Zr, V, Nb, Al | Predicted: Ti, Zr, V, Nb, Al
#
# Accuracy for Fold 1: 100.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Co       1.00      1.00      1.00         6
#           Cr       1.00      1.00      1.00         6
#           Fe       1.00      1.00      1.00         6
#           Mn       1.00      1.00      1.00         5
#           Ni       1.00      1.00      1.00         5
#           Ti       1.00      1.00      1.00         2
#           Zr       1.00      1.00      1.00         2
#           Hf       1.00      1.00      1.00         1
#            V       1.00      1.00      1.00         1
#           Nb       1.00      1.00      1.00         2
#           Ta       1.00      1.00      1.00         2
#           Mo       1.00      1.00      1.00         2
#           Al       1.00      1.00      1.00         3
#           Cu       1.00      1.00      1.00         2
#            C       1.00      1.00      1.00         1
#            N       1.00      1.00      1.00         1
#            I       0.00      0.00      0.00         0
#            B       0.00      0.00      0.00         0
#            S       0.00      0.00      0.00         0
#            P       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            F       0.00      0.00      0.00         0
#           Si       1.00      1.00      1.00         2
#            H       0.00      0.00      0.00         0
#            W       1.00      1.00      1.00         1
#           Mg       1.00      1.00      1.00         1
#
#    micro avg       1.00      1.00      1.00        51
#    macro avg       0.73      0.73      0.73        51
# weighted avg       1.00      1.00      1.00        51
#  samples avg       1.00      1.00      1.00        51

# %%
import json
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt

# List of valid chemical elements (symbols) in the periodic table
# Removed radioactive elements and noble gases.
periodic_elements = {
    "H", "Li", "Be", "B", "C", "N", "O", "F", "Na", "Mg", "Al", "Si", "P", "S", "Cl", "K", "Ca",
    "Sc", "Ti", "V", "Cr", "Mn", "Fe", "Co", "Ni", "Cu", "Zn", "Ga", "Ge", "As", "Se", "Br", "Rb", "Sr", "Y",
    "Zr", "Nb", "Mo", "Ru", "Rh", "Pd", "Ag", "Cd", "In", "Sn", "Sb", "Te", "I", "Cs", "Ba", "La", "Ce", "Pr",
    "Nd", "Sm", "Eu", "Gd", "Tb", "Dy", "Ho", "Er", "Tm", "Yb", "Lu", "Hf", "Ta", "W", "Re", "Os", "Ir", "Pt",
    "Au", "Hg", "Tl", "Pb", "Bi"
}

# Load the data
with open('admin.materials_100.json') as f:
    data = json.load(f)

# Extracting composition data and converting to DataFrame
compositions = []
titles = []

for entry in data:
    if not entry.get('composition'):
        continue
    composition = {element: 1 for element in entry['composition'].keys() if element in periodic_elements}
    titles.append(entry['title'])
    compositions.append(composition)

# Convert compositions to DataFrame
df = pd.DataFrame(compositions)
df.fillna(0, inplace=True)  # Fill NaN with 0 for elements not present

# Define features (X) and labels (y)
X = df.copy()
y = df.copy()

# Initialize the decision tree classifier
classifier = DecisionTreeClassifier(random_state=42)

# Set up K-fold cross-validation
kf = KFold(n_splits=10, shuffle=True, random_state=42)
fold = 1

for train_index, test_index in kf.split(X):
    print(f"\n{'='*30} Fold {fold} Results {'='*30}")
    fold += 1

    # Split data into train and test sets for this fold
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
    titles_test = [titles[i] for i in test_index]

    # Train the single decision tree classifier
    classifier.fit(X_train, y_train)

    # Predict on the test set
    y_pred = classifier.predict(X_test)

    # Print actual vs predicted compositions with titles
    print("Title | Actual | Predicted")
    for title, actual, predicted in zip(titles_test, y_test.values, y_pred):
        actual_labels = ', '.join([col for col, val in zip(y.columns, actual) if val == 1])
        predicted_labels = ', '.join([col for col, val in zip(y.columns, predicted) if val == 1])
        print(f"{title} | Actual: {actual_labels} | Predicted: {predicted_labels}")

    # Calculate and print accuracy and classification report
    accuracy = accuracy_score(y_test, y_pred) * 100
    print(f"\nAccuracy for Fold {fold-1}: {accuracy:.2f}%")

    print("\nClassification Report for Fold:")
    print(classification_report(y_test, y_pred, target_names=y.columns, zero_division=0))

    # Plot the decision tree
    plt.figure(figsize=(20, 10))
    plot_tree(classifier, feature_names=X.columns, class_names=y.columns, filled=True)
    plt.title(f"Decision Tree for Fold {fold-1}")
    plt.show()

    # Break after the first fold if you want to see just one tree
    break
# Out:
# ============================== Fold 1 Results ==============================
# Title | Actual | Predicted
# paper-150 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-133 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-1 | Actual: Co, Cr, Fe, Mn, Cu, Si | Predicted: Co, Cr, Fe, Mn, Cu, Si
# paper-110 | Actual: Al, Si, Mg | Predicted: Cr, V, Nb, Mo, Al
# paper-131 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-133 | Actual: Co, Cr, Fe, Mn, Ni | Predicted: Co, Cr, Fe, Mn, Ni
# paper-144 | Actual: Ti, Zr, Hf, Ta, Mo, N | Predicted: Ti, Zr, Hf, Ta, Mo
# paper-210 | Actual: Nb, Ta, Mo, C, W | Predicted: Nb, Ta, Mo, C, W
# paper-218 | Actual: Co, Cr, Fe, Ni, Al, Cu | Predicted: Co, Cr, Fe, Ni, Al, Cu
# paper-229 | Actual: Ti, Zr, V, Nb, Al | Predicted: Ti, Zr, V, Nb, Al
#
# Accuracy for Fold 1: 80.00%
#
# Classification Report for Fold:
#               precision    recall  f1-score   support
#
#           Co       1.00      1.00      1.00         6
#           Cr       0.86      1.00      0.92         6
#           Fe       1.00      1.00      1.00         6
#           Mn       1.00      1.00      1.00         5
#           Ni       1.00      1.00      1.00         5
#           Ti       1.00      1.00      1.00         2
#           Zr       1.00      1.00      1.00         2
#           Hf       1.00      1.00      1.00         1
#            V       0.50      1.00      0.67         1
#           Nb       0.67      1.00      0.80         2
#           Ta       1.00      1.00      1.00         2
#           Mo       0.67      1.00      0.80         2
#           Al       1.00      1.00      1.00         3
#           Cu       1.00      1.00      1.00         2
#            C       1.00      1.00      1.00         1
#            N       0.00      0.00      0.00         1
#            I       0.00      0.00      0.00         0
#            B       0.00      0.00      0.00         0
#            S       0.00      0.00      0.00         0
#            P       0.00      0.00      0.00         0
#            O       0.00      0.00      0.00         0
#            F       0.00      0.00      0.00         0
#           Si       1.00      0.50      0.67         2
#            H       0.00      0.00      0.00         0
#            W       1.00      1.00      1.00         1
#           Mg       0.00      0.00      0.00         1
#
#    micro avg       0.92      0.94      0.93        51
#    macro avg       0.60      0.63      0.61        51
# weighted avg       0.91      0.94      0.92        51
#  samples avg       0.92      0.92      0.92        51

# %%
plot_tree(classifier, feature_names=X.columns, class_names=y.columns, filled=True, impurity=False, label='none')
# Out:
# [Text(0.5, 0.75, 'Co <= 0.5\n90\n[39, 51]\nCr'),
#  Text(0.25, 0.25, '39\n[39, 0]\nCo'),
#  Text(0.375, 0.5, 'True  '),
#  Text(0.75, 0.25, '51\n[0, 51]\nCr'),
#  Text(0.625, 0.5, '  False')]

# %%
# Plot the decision tree without the value attribute
plt.figure(figsize=(20, 10))
plot_tree(
    classifier,
    feature_names=X.columns,
    class_names=y.columns,
    filled=True,
    impurity=False,    # Remove impurity (like Gini or entropy)
    label='none'       # Remove 'value' and sample counts
)
plt.title(f"Decision Tree for Fold {fold-1}")
plt.show()

# %%
plt.figure(figsize=(40, 20))
plot_tree(classifier, feature_names=X.columns, class_names=y.columns, filled=True, fontsize=12)
plt.title(f"Decision Tree for Fold {fold-1}")
plt.savefig('decision_tree.png', dpi=300)  # Save the image in high resolution
plt.show()

# %%
import json
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# List of valid chemical elements (symbols) in the periodic table
periodic_elements = {
    "H", "Li", "Be", "B", "C", "N", "O", "F", "Na", "Mg", "Al", "Si", "P", "S", "Cl", "K", "Ca",
    "Sc", "Ti", "V", "Cr", "Mn", "Fe", "Co", "Ni", "Cu", "Zn", "Ga", "Ge", "As", "Se", "Br", "Rb", "Sr", "Y",
    "Zr", "Nb", "Mo", "Ru", "Rh", "Pd", "Ag", "Cd", "In", "Sn", "Sb", "Te", "I", "Cs", "Ba", "La", "Ce", "Pr",
    "Nd", "Sm", "Eu", "Gd", "Tb", "Dy", "Ho", "Er", "Tm", "Yb", "Lu", "Hf", "Ta", "W", "Re", "Os", "Ir", "Pt",
    "Au", "Hg", "Tl", "Pb", "Bi"
}

# Load the data
with open('admin.materials_100.json') as f:
    data = json.load(f)

# Extracting composition data and converting to DataFrame
compositions = []
titles = []

for entry in data:
    if not entry.get('composition'):
        continue
    composition = {element: 1 for element in entry['composition'].keys() if element in periodic_elements}
    titles.append(entry['title'])
    compositions.append(composition)

# Convert compositions to DataFrame
df = pd.DataFrame(compositions)
df.fillna(0, inplace=True)

# Features and labels (multi-label classification)
X = df.copy()
y = df.copy()

# Initialize Decision Tree Classifier with depth limit for better visualization
classifier = DecisionTreeClassifier(random_state=42, max_depth=3)

# Using first fold from K-Fold for training and visualization
kf = KFold(n_splits=10, shuffle=True, random_state=42)
train_index, test_index = next(kf.split(X))

X_train, X_test = X.iloc[train_index], X.iloc[test_index]
y_train, y_test = y.iloc[train_index], y.iloc[test_index]

# Training on the first element as a sample (to visualize a single tree)
element_to_visualize = y.columns[0]
classifier.fit(X_train, y_train[element_to_visualize])

# Plotting the decision tree
plt.figure(figsize=(60, 30))
plot_tree(classifier,
          feature_names=X.columns,
          class_names=['Absent', 'Present'],
          filled=True,
          fontsize=14,
          rounded=True)
plt.title(f"Decision Tree for Element: {element_to_visualize}", fontsize=20)
plt.tight_layout()
plt.savefig('decision_tree_visualization.svg', format='svg')  # Save as SVG for clarity
plt.show()

# %%
import json
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# List of valid chemical elements (symbols) in the periodic table
periodic_elements = {
    "H", "Li", "Be", "B", "C", "N", "O", "F", "Na", "Mg", "Al", "Si", "P", "S", "Cl", "K", "Ca",
    "Sc", "Ti", "V", "Cr", "Mn", "Fe", "Co", "Ni", "Cu", "Zn", "Ga", "Ge", "As", "Se", "Br", "Rb", "Sr", "Y",
    "Zr", "Nb", "Mo", "Ru", "Rh", "Pd", "Ag", "Cd", "In", "Sn", "Sb", "Te", "I", "Cs", "Ba", "La", "Ce", "Pr",
    "Nd", "Sm", "Eu", "Gd", "Tb", "Dy", "Ho", "Er", "Tm", "Yb", "Lu", "Hf", "Ta", "W", "Re", "Os", "Ir", "Pt",
    "Au", "Hg", "Tl", "Pb", "Bi"
}

# Load the data
with open('admin.materials_100.json') as f:
    data = json.load(f)

# Extracting composition data and converting to DataFrame
compositions = []
titles = []

for entry in data:
    if not entry.get('composition'):
        continue
    composition = {element: 1 for element in entry['composition'].keys() if element in periodic_elements}
    titles.append(entry['title'])
    compositions.append(composition)

# Convert compositions to DataFrame
df = pd.DataFrame(compositions)
df.fillna(0, inplace=True)

# Features and labels (multi-label classification)
X = df.copy()
y = df.copy()

# Initialize Decision Tree Classifier with depth limit for better visualization
classifier = DecisionTreeClassifier(random_state=42, max_depth=3)

# Using first fold from K-Fold for training and visualization
kf = KFold(n_splits=10, shuffle=True, random_state=42)
train_index, test_index = next(kf.split(X))

X_train, X_test = X.iloc[train_index], X.iloc[test_index]
y_train, y_test = y.iloc[train_index], y.iloc[test_index]

# Training on the first element as a sample (to visualize a single tree)
element_to_visualize = y.columns[0]
classifier.fit(X_train, y_train[element_to_visualize])

# Plotting the decision tree with values
plt.figure(figsize=(60, 30))
plot_tree(classifier,
          feature_names=X.columns,
          class_names=['Absent', 'Present'],
          filled=True,
          fontsize=14,
          rounded=True,
          proportion=False,  # Show raw counts instead of proportions
          precision=2)       # Display numbers with 2 decimal precision

plt.title(f"Decision Tree for Element: {element_to_visualize}", fontsize=20)
plt.tight_layout()
plt.savefig('decision_tree_with_values.svg', format='svg')  # Save as SVG for better clarity
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# Plotting the decision tree without node values
plt.figure(figsize=(40, 20))
plot_tree(classifier,
          feature_names=X.columns,   # Display feature names
          class_names=y.columns,     # Display class names
          filled=True,               # Fill nodes with color
          fontsize=12,               # Font size for readability
          impurity=False,            # Remove Gini impurity values
          proportion=False,          # No proportion values
          label='none')              # Remove class and sample counts

plt.title(f"Decision Tree for Fold {fold-1}")
plt.savefig('decision_tree.png', dpi=300)  # Save the image in high resolution
plt.show()
